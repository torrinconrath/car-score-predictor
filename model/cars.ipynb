# %% [markdown]
# Current Model Notebook

# %%
# Create the dataset

import numpy as np
import pandas as pd
from datetime import datetime
import random as rand
from sklearn.feature_selection import SelectPercentile, f_regression
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
import torch
import json
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import joblib
import warnings
from transformers import logging
import joblib

# Ignore specific warnings and logs
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning, module='tqdm')
logging.set_verbosity_error() 

# Read the file
df = pd.read_csv("training_cars_data.csv")

# Make Car Model into two different columns
if 'Car Model' in df.columns:
    df[['Year', 'Model']] = df['Car Model'].str.extract(r'(\d{4})\s(.*)')
    df = df.drop(columns=['Car Model'])

if 'Price (USD)' in df.columns:
    df = df.rename(columns={'Price (USD)': 'Price'})

if 'Dealer Name' in df.columns:
    df = df.rename(columns={'Dealer Name': 'Dealer'})

# Standardize all matching rows to 'Certified'
df['Condition'] = df['Condition'].apply(
    lambda x: 'Certified' if 'certified' in str(x).lower() else x
)
# Clean condition column
df['Condition'] = df['Condition'].replace([
    'Prequalify now', 'stock_type', 'New & Used', np.nan
], 'Other')

# List of columns to clean
columns_to_clean = ['Monthly Payment', 'Mileage', 'Price', 'Year']

# Apply cleaning function to all specified columns
df[columns_to_clean] = df[columns_to_clean].apply(lambda x: x.str.replace(r'\D', '', regex=True))

# Convert to numeric while preserving NaNs
df[columns_to_clean] = df[columns_to_clean].apply(pd.to_numeric, errors='coerce')

# Set empty Mileage values to 0
df['Mileage'] = df['Mileage'].fillna(0)

# Synthetic feature generation
def random_accident(row):
    return rand.choices([1, 0], weights=[30, 70], k=1)[0]  # 1 = accident, 0 = no accident

def random_owners(row):
    numbers = [0, 1, 2, 3, 4]
    weights = [40, 40, 30, 20, 10]
    return rand.choices(numbers, weights=weights, k=1)[0] 

def random_usage(row):
    return rand.choices([1, 0], weights=[80, 20], k=1)[0]  # 1 = personal use, 0 = not personal

# Apply the random features
df['Accidents'] = df.apply(random_accident, axis=1)
df['Owners'] = df.apply(random_owners, axis=1)
df['Usage'] = df.apply(random_usage, axis=1) 

# Feature engineering
current_year = datetime.now().year
df['Age'] = current_year - df['Year']
df['MilesPerYear'] = df['Mileage'] / (df['Age'] + 1)
df['PricePerMile'] = df['Price'] / (df['Mileage'] + 1)

# Hot-one encoding
df = pd.get_dummies(df, columns=['Condition', 'Model', 'Dealer'], drop_first=False)

# def simple_scoring(row):
#     if pd.isna(row['Mileage']) or pd.isna(row['Price']) or pd.isna(row['Year']):
#         return np.nan
    
#     age = current_year - row['Year']
#     price_score = row['Price'] / 2000  
#     mileage_score = row['Mileage'] / 2500    
#     age_score = age * 5                     
    
#     weighted_sum = (0.5 * price_score) + (0.4 * mileage_score) + (0.1 * age_score)
    
#     if row['Accidents'] == 1:
#         weighted_sum += 15  
    
#     if row['Owners'] == 2:
#         weighted_sum += 5
#     elif row['Owners'] > 2:
#         weighted_sum += 10
    
#     if row['Usage'] == 0:  # Commercial usage penalty
#         weighted_sum += 10
    
#     return weighted_sum

 
# df['Score'] = df.apply(simple_scoring, axis=1)

MEDIAN_PRICE = 25000  # median price baseline
MAX_MILEAGE = 250000
MAX_AGE = 30

def enhanced_scoring(row):
    # Check essential columns early
    if pd.isna(row.get('Mileage')) or pd.isna(row.get('Year')):
        return np.nan

    age = current_year - row['Year']
    if age < 0:
        age = 0  # avoid negative age if year is in future

    # Determine price_for_score
    price = row.get('Price')
    monthly_payment = row.get('Monthly Payment')

    if not pd.isna(price):
        price_for_score = price
    elif not pd.isna(monthly_payment):
        price_for_score = monthly_payment * 60  # estimate full price (5 years)
    else:
        return np.nan  # no price info at all

    # Normalize and clamp values
    clamped_mileage = min(row['Mileage'], MAX_MILEAGE)
    clamped_age = min(age, MAX_AGE)

    # Scores (log scale for price, power scale for others)
    price_score = np.log1p(price_for_score / MEDIAN_PRICE) * 100
    mileage_score = 100 * ((clamped_mileage / MAX_MILEAGE) ** 0.8)
    age_score = 100 * ((clamped_age / MAX_AGE) ** 0.7)

    weighted_sum = (0.55 * price_score) + (0.35 * mileage_score) + (0.10 * age_score)

    # Condition adjustment
    condition_new = row.get('Condition_New', 0) == 1
    condition_certified = row.get('Condition_Certified', 0) == 1
    condition_used = row.get('Condition_Used', 0) == 1

    if condition_new:
        weighted_sum -= 20
    elif condition_certified:
        weighted_sum -= 15
    elif not condition_used:
        weighted_sum += 5  # penalty for unknown condition

    # Accidents adjustment
    accidents = row.get('Accidents', 0)
    if accidents == 1:
        weighted_sum += 10
    elif accidents > 1:
        weighted_sum += 15  # harsher penalty for multiple accidents

    # Owners adjustment (penalties scale moderately)
    owners = row.get('Owners', 1)  # default 1 if missing
    if owners == 2:
        weighted_sum += 8
    elif owners > 2:
        weighted_sum += 8 + 3 * (owners - 2)  # scaled penalty

    # Usage adjustment
    usage = row.get('Usage', 1)  # assume 1 = non-commercial, 0 = commercial
    if usage == 0:
        # More penalty for commercial, scales with age
        weighted_sum += 15 * (1 + clamped_age / MAX_AGE)

    # Mileage per year adjustment
    years_used = age if age > 0 else 1
    miles_per_year = row['Mileage'] / years_used

    if miles_per_year < 7500:
        weighted_sum -= 5  # low mileage is good
    elif miles_per_year > 15000:
        weighted_sum += 10  # high mileage is bad

    return weighted_sum

# Apply to dataframe
df['Score'] = df.apply(enhanced_scoring, axis=1)

# Create training and testing data
df = df.dropna(subset=['Monthly Payment', 'Mileage', 'Price', 'Year', 'Score'])

X = df.drop(columns=['Score'])
y = df['Score']

# Feature selection (keep features with top 10% relevance = drop bottom 90%)
selector = SelectPercentile(f_regression, percentile=50)
X_selected = selector.fit_transform(X, y)

# Get selected feature names
selected_features = [X.columns[i] for i in selector.get_support(indices=True)]
print(f"Selected {len(selected_features)} features:")
print(selected_features)

# Update feature list
model_features = selected_features
with open('model_features.json', 'w') as f:
    json.dump(model_features, f)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_selected)

joblib.dump(scaler, 'scaler.pkl')

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y.values.reshape(-1, 1), test_size=0.2, random_state=42)

# Save X_train values
X_train_df = pd.DataFrame(X_train, columns=model_features)
X_train_df.to_pickle("X_train.pkl")

# XGBoost Benchmarking
print("\nXGBoost Benchmark:")
xgb = XGBRegressor(n_estimators=1000, learning_rate=0.01, early_stopping_rounds=50, random_state=42)
xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)

xgb_pred = xgb.predict(X_test)
xgb_mse = mean_squared_error(y_test, xgb_pred)
xgb_r2 = r2_score(y_test, xgb_pred)
xgb_mae = mean_absolute_error(y_test, xgb_pred)

print(f"XGBoost MSE: {xgb_mse:.2f}")
print(f"XGBoost R²: {xgb_r2:.4f}")
print(f"XGBoost MAE: {xgb_mae:.2f}")

# Scale target
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

joblib.dump(y_scaler, 'model_scaler.pkl')

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_scaled.reshape(-1, 1), dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_scaled.reshape(-1, 1), dtype=torch.float32)

# Neural Network Implementation

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("\nUsing device:", device)

# Dataset Setup
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Model Definition
class ImprovedMLP(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.2),
            nn.Linear(64, 1)
        )
    
    def forward(self, x):
        return self.net(x)

# Training with Early Stopping
model = ImprovedMLP(X_train.shape[1]).to(device)
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

best_loss = float('inf')
patience = 100
no_improve = 0

for epoch in range(200):
    model.train()
    running_loss = 0.0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        running_loss += loss.item() * batch_X.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    
    # Validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs = model(batch_X)
            val_loss += criterion(outputs, batch_y).item() * batch_X.size(0)
    
    val_loss /= len(test_loader.dataset)
    
    if val_loss < best_loss:
        best_loss = val_loss
        no_improve = 0
        torch.save(model.state_dict(), 'best_car_model.pth')

    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
    
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}: Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}")

# Load best model
model.load_state_dict(torch.load('best_car_model.pth'))
y_scaler = joblib.load('model_scaler.pkl')

# Evaluation
model.eval()
all_preds, all_targets = [], []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        outputs = model(batch_X)
        all_preds.append(outputs.cpu())
        all_targets.append(batch_y.cpu())

predictions = torch.cat(all_preds).numpy()
targets = torch.cat(all_targets).numpy()

preds_rescaled = y_scaler.inverse_transform(predictions)
y_true_rescaled = y_scaler.inverse_transform(targets)

print("All predictions (rescaled):")
print(preds_rescaled.flatten())


mse = mean_squared_error(y_true_rescaled, preds_rescaled)
r2 = r2_score(y_true_rescaled, preds_rescaled)
mae = mean_absolute_error(y_true_rescaled, preds_rescaled)

tolerance = 5
within_tolerance = np.abs(y_true_rescaled - preds_rescaled) <= tolerance
accuracy = np.mean(within_tolerance) * 100

print("\nFinal Evaluation:")
print(f"Test MSE: {mse:.2f}")
print(f"Test R²: {r2:.4f}")
print(f"Test MAE: {mae:.2f}")
print(f"Accuracy (within ±{tolerance}): {accuracy:.2f}%")
# Out:
# Selected 1718 features:
# ['Mileage', 'Price', 'Monthly Payment', 'Year', 'Accidents', 'Owners', 'Usage', 'Age', 'MilesPerYear', 'PricePerMile', 'Condition_Certified', 'Condition_New', 'Condition_Other', 'Condition_Used', 'Model_Acura ILX', 'Model_Acura Integra', 'Model_Acura Integra A-SPEC', 'Model_Acura Integra A-SPEC w/ Technology', 'Model_Acura Integra A-Spec', 'Model_Acura Integra A-Spec Tech Package', 'Model_Acura Integra A-Spec Technology', 'Model_Acura Integra Base', 'Model_Acura Integra Type S', 'Model_Acura Integra W/A-SPEC TECHNOLOGY PACKAGE', 'Model_Acura MDX 3.5L', 'Model_Acura MDX 3.5L w/Technology & Entertainment Pkgs', 'Model_Acura MDX A-SPEC', 'Model_Acura MDX A-Spec', 'Model_Acura MDX A-Spec Advance', 'Model_Acura MDX A-Spec Package', 'Model_Acura MDX Advance', 'Model_Acura MDX Base', 'Model_Acura MDX SH-AWD Technology', 'Model_Acura MDX Sport Hybrid 3.0L w/Advance Package', 'Model_Acura NSX Base', 'Model_Acura NSX T', 'Model_Acura RDX A-Spec Advance', 'Model_Acura RDX Base', 'Model_Acura RDX Technology Package', 'Model_Acura RDX W/A-SPEC PACKAGE', 'Model_Acura TLX A-Spec', 'Model_Acura TLX Type S', 'Model_Acura TLX V6 A-Spec', 'Model_Acura ZDX Base', 'Model_Alfa Romeo Stelvio Base', 'Model_Alfa Romeo Stelvio Quadrifoglio', 'Model_Alfa Romeo Tonale AWD', 'Model_Alfa Romeo Tonale Base', 'Model_Alfa Romeo Tonale Veloce', 'Model_Alfa Romeo Tonale Veloce EAWD', 'Model_Am General Hummer Wagon', 'Model_Aston Martin DB12 Coupe', 'Model_Aston Martin DB9 Volante', 'Model_Aston Martin DBS Superleggera', 'Model_Aston Martin DBS ULTIMATE 770', 'Model_Aston Martin DBS Volante', 'Model_Aston Martin DBX 707', 'Model_Aston Martin DBX SUV', 'Model_Aston Martin V12 Vanquish Base', 'Model_Aston Martin Vanquish Volante', 'Model_Aston Martin Vantage AMR PROTOTYPE', 'Model_Aston Martin Vantage Coupe', 'Model_Aston Martin Vantage Roadster', 'Model_Aston Martin Virage Base', 'Model_Audi A4 2.0T Premium', 'Model_Audi A4 2.0T Technik', 'Model_Audi A4 45 Prestige', 'Model_Audi A4 45 S line Premium Plus', 'Model_Audi A4 allroad Premium Plus', 'Model_Audi A5 Sportback 45 S Line Premium Plus', 'Model_Audi A5 Sportback S-Line Prestige', 'Model_Audi A6 55 Premium Plus', 'Model_Audi A8 e L 60', 'Model_Audi Q3 45 S line Premium Plus', 'Model_Audi Q3 Premium', 'Model_Audi Q3 Premium 45 TFSI S line quattro Tiptronic', 'Model_Audi Q3 S line Premium', 'Model_Audi Q5 40 Premium', 'Model_Audi Q5 40 Premium Plus', 'Model_Audi Q5 45 Premium Plus', 'Model_Audi Q5 45 S line Premium', 'Model_Audi Q5 45 S line quattro Premium', 'Model_Audi Q5 55 S line Premium', 'Model_Audi Q5 55 S line Prestige', 'Model_Audi Q5 S-Line Prestige', 'Model_Audi Q5 Sportback S-Line Premium Plus', 'Model_Audi Q5 e 55 S line Premium Plus', 'Model_Audi Q6 e-tron Prestige', 'Model_Audi Q7 3.0T Premium Plus', 'Model_Audi Q7 45 Premium', 'Model_Audi Q7 45 Premium Plus', 'Model_Audi Q7 55 Premium', 'Model_Audi Q7 55 Premium Plus', 'Model_Audi Q7 55 Prestige', 'Model_Audi Q7 Premium', 'Model_Audi Q7 Premium Plus', 'Model_Audi Q8 55 Premium Plus', 'Model_Audi Q8 55 Prestige', 'Model_Audi Q8 Premium Plus', 'Model_Audi Q8 Prestige', 'Model_Audi RS 3 2.5T', 'Model_Audi RS 3 TFSI quattro S tronic', 'Model_Audi RS 5', 'Model_Audi RS 5 2.9T', 'Model_Audi RS 5 4.2', 'Model_Audi RS 7 4.0T Prestige', 'Model_Audi RS 7 4.0T quattro', 'Model_Audi RS Q8 4.0T', 'Model_Audi RS Q8 4.0T quattro', 'Model_Audi RS e-tron GT quattro', 'Model_Audi S e-tron GT Premium Plus', 'Model_Audi S3 Premium Plus TFSI quattro S tronic', 'Model_Audi S4 3.0T Premium Plus', 'Model_Audi S5 3.0T Premium Plus', 'Model_Audi S6 2.9 TFSI Prestige', 'Model_Audi S6 2.9T quattro Premium', 'Model_Audi S6 Premium Plus', 'Model_Audi S6 Prestige', 'Model_Audi S6 Prestige TFSI quattro Tiptronic', 'Model_Audi SQ7 4.0T Premium Plus', 'Model_Audi SQ8 4.0T Premium Plus', 'Model_Audi SQ8 4.0T Prestige', 'Model_Audi SQ8 4.0T quattro Premium Plus', 'Model_Audi TT RS 2.5T', 'Model_Audi TTS 2.0T', 'Model_Audi e-tron GT Premium Plus', 'Model_Audi e-tron GT Prestige', ' ...
#
# XGBoost Benchmark:
# XGBoost MSE: 3.57
# XGBoost R²: 0.9930
# XGBoost MAE: 1.08
#
# Using device: cuda
# Epoch 10: Train Loss: 0.0659, Val Loss: 0.0633
# Epoch 20: Train Loss: 0.0406, Val Loss: 0.0525
# Epoch 30: Train Loss: 0.0349, Val Loss: 0.0737
# Epoch 40: Train Loss: 0.0302, Val Loss: 0.0437
# Epoch 50: Train Loss: 0.0272, Val Loss: 0.0384
# Epoch 60: Train Loss: 0.0269, Val Loss: 0.0366
# Epoch 70: Train Loss: 0.0248, Val Loss: 0.0384
# Epoch 80: Train Loss: 0.0227, Val Loss: 0.0379
# Epoch 90: Train Loss: 0.0236, Val Loss: 0.0371
# Epoch 100: Train Loss: 0.0217, Val Loss: 0.0372
# Epoch 110: Train Loss: 0.0231, Val Loss: 0.0344
# Epoch 120: Train Loss: 0.0209, Val Loss: 0.0353
# Epoch 130: Train Loss: 0.0213, Val Loss: 0.0409
# Epoch 140: Train Loss: 0.0193, Val Loss: 0.0350
# Epoch 150: Train Loss: 0.0191, Val Loss: 0.0375
# Epoch 160: Train Loss: 0.0194, Val Loss: 0.0393
# Epoch 170: Train Loss: 0.0194, Val Loss: 0.0385
# Epoch 180: Train Loss: 0.0182, Val Loss: 0.0387
# Epoch 190: Train Loss: 0.0195, Val Loss: 0.0393
# Epoch 200: Train Loss: 0.0180, Val Loss: 0.0427
# All predictions (rescaled):
# [63.72521  75.401924 62.876293 ... 84.80892  47.5585   64.49379 ]
#
# Final Evaluation:
# Test MSE: 54.38
# Test R²: 0.8933
# Test MAE: 4.29
# Accuracy (within ±3): 57.10%

# %%
# Create the LLM input processor
from transformers import pipeline
import re
import json
import random
import os

# Get base dir of current file
BASE_DIR = os.getcwd()
SCRIPT_DIR = os.path.abspath(os.path.join(BASE_DIR, "..", "scripts"))

class CarScorePredictor:
    def __init__(self):
        
        self.input_scaler = joblib.load('scaler.pkl')
        self.output_scaler = joblib.load('model_scaler.pkl')

        # Load model features
        with open('model_features.json', 'r') as f:
            self.model_features = json.load(f)

        with open(os.path.join(SCRIPT_DIR, 'all_make_model_keys.json'), 'r') as f:
            self.model_slugs = json.load(f)
        
        self.model_types = [slug.replace('_', ' ').replace('-', ' ').title() for slug in self.model_slugs]

        # Get mean values for imputation from the training data
        self.X_train_df = pd.read_pickle("X_train.pkl")
        self.default_values = self.X_train_df.mean()

        # List of known categorical fields that were one-hot encoded
        self.one_hot_prefixes = ['Condition_', 'Model_', 'Dealer_']  
        
        # Initialize the neural network
        self.model = ImprovedMLP(input_size=len(self.model_features))  
        self.model.load_state_dict(torch.load('best_car_model.pth', weights_only=True))
        self.model.to(device)
        self.model.eval()
        
        # Initialize LLM for information extraction
        self.ner_pipeline = pipeline(
            "token-classification",
            model="dslim/bert-base-NER",
            aggregation_strategy="simple"
        )
        
        # Initialize LLM for text understanding
        self.qa_pipeline = pipeline(
            "question-answering",
            model="distilbert-base-uncased-distilled-squad"
        )

    def extract_car_info(self, text):
        """Extract structured car information from natural language"""
        # Extract entities using NER
        entities = self.ner_pipeline(text)

        # Initialize default values
        car_info = {
            'Year': None,
            'Model': None,
            'Mileage': None,
            'Price': None,
            'Condition': None,
            'Dealer': None,
            'Monthly Payment': None,
            'Accidents': 0,  # Default to no accidents
            'Owners': 1,     # Default to 1 owner
            'Usage': 1       # Default to personal use (1)
        }


        # Simple regex-based extractions for numerical fields
        mileage_match = re.search(r'\b([0-9,]+)\s*(mi|miles)\b\.?', text, re.IGNORECASE)
        price_match = re.search(r'\$([0-9,]+)\b(?![a-zA-Z/]| per)', text)
        payment_match = re.search(r'\$([0-9,]+)\s*(?:/mo|per month)', text, re.IGNORECASE)
        year_match = re.search(r'\b(20\d{2}|19\d{2})\b', text)

        if mileage_match:
            car_info['Mileage'] = int(mileage_match.group(1).replace(',', ''))
        if price_match:
            car_info['Price'] = int(price_match.group(1).replace(',', ''))
        if payment_match:
            car_info['Monthly Payment'] = int(payment_match.group(1).replace(',', ''))
        if year_match:
            car_info['Year'] = int(year_match.group(0))

        # Extract accident information
        if re.search(r'accidents?|accident history', text, re.IGNORECASE):
            car_info['Accidents'] = 1

        # Extract owner count
        owners_match = re.search(r'(\d+)\s*(owners?|previous owners?)', text, re.IGNORECASE)
        if owners_match:
            car_info['Owners'] = int(owners_match.group(1))
        elif re.search(r'one\s*owner|single owner', text, re.IGNORECASE):
            car_info['Owners'] = 1
        elif re.search(r'two\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 2
        elif re.search(r'three\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 3
        elif re.search(r'four\+?\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 4

        # Extract usage type (mapped to your binary encoding)
        if re.search(r'commercial|business|fleet', text, re.IGNORECASE):
            car_info['Usage'] = 0  # Not personal use

        # Pull entities from NER
        for ent in entities:
            label = ent['entity_group']
            word = ent['word']

            if label == 'ORG':
                car_info['Dealer'] = word
            elif label == 'MISC' or label == 'PRODUCT':
                car_info['Model'] = word
            elif label == 'DATE' and not car_info['Year']:
                try:
                    car_info['Year'] = int(re.search(r'\d{4}', word).group(0))
                except:
                    pass

        # Try to find a matching model from the list
        found_model = None
        for model in self.model_types:
            pattern = re.compile(rf'\b{re.escape(model)}\b', re.IGNORECASE)
            if pattern.search(text):
                found_model = model
                break

        if found_model:
            car_info['Model'] = found_model

        # Extract sales condition like New, Used, Certified, etc.
        condition_match = re.search(r'\b(New|Used|Certified(?: Pre-Owned)?)\b', text, re.IGNORECASE)
        if condition_match:
            car_info['Condition'] = condition_match.group(1).title()

        if not car_info['Dealer']:
            dealer_match = re.search(
                r'\b(?:at dealer|dealer:|at)\s+([A-Z][\w&.,\- ]{2,100})',
                text,
                re.IGNORECASE
            )
            if dealer_match:
                # Clean extra whitespace and strip trailing punctuation
                dealer_name = dealer_match.group(1).strip().rstrip('.,')
                dealer_name = re.sub(r'\bdealer\b', '', dealer_name, flags=re.IGNORECASE).strip()
                car_info['Dealer'] = dealer_name

        return car_info
    
    def prepare_features(self, car_info):
        """Convert extracted car info into the model input vector"""
        # Initialize feature row with zeros
        feature_vector = np.zeros(len(self.model_features))
        feature_df = pd.DataFrame([feature_vector], columns=self.model_features)

        # Fill in numerical fields
        for col in ['Year', 'Mileage', 'Price', 'Monthly Payment', 'Accidents', 'Owners']:
            val = car_info.get(col)
            if val is not None:
                feature_df.at[0, col] = val
            else:
                feature_df.at[0, col] = self.default_values[col]

        # Fill in one-hot fields
        for prefix in self.one_hot_prefixes:
            value = car_info.get(prefix)
            if value is not None:
                encoded = f"{prefix}_{value}"
                if encoded in self.model_features:
                    feature_df.at[0, encoded] = 1.0

        # Apply input scaling
        scaled_features = self.input_scaler.transform(feature_df.values)
        
        # Convert to tensor
        return torch.tensor(scaled_features, dtype=torch.float32).to(device)

    
    def predict_score(self, text_input):
        """Main prediction pipeline"""
        # Extract information from text
        car_info = self.extract_car_info(text_input)
        print("Extracted car info:", car_info)
        
        # Prepare features for model
        features_tensor = self.prepare_features(car_info)
        
        # Make prediction
        with torch.no_grad():
            prediction = self.model(features_tensor)
            score = self.output_scaler.inverse_transform(prediction.cpu().numpy().reshape(-1, 1))
        
        return score[0][0]

# Example usage
if __name__ == "__main__":
    predictor = CarScorePredictor()

    # Define options for different fields
    years = [str(y) for y in range(1998, 2023)]

    # Extract model names from the one-hot encoded features (removing "Model_" prefix)
    sample_models = [feature.replace("Model_", "") for feature in model_features if feature.startswith("Model_")]
    mileages = [f"{x:,}" for x in range(0, 250001, 5000)]
    prices = [f"${x:,}" for x in range(4000, 120001, 2000)]
    conditions = [feature.replace("Condition_", "") for feature in model_features if feature.startswith("Condition_")]
    dealers = [feature.replace("Dealer_", "") for feature in model_features if feature.startswith("Dealer_")]
    payments = [f"${x:,}" for x in range(120, 3001, 50)]
    
    # Options for additional features
    accident_options = ["no accidents", "accident reported", "clean history", "1 accident", "accident history"]
    owner_options = ["1 owner", "2 owners", "3 owners", "4+ owners", "single owner", "one previous owner"]
    usage_options = ["private use", "commercial use", "fleet use", "personal use", "business use"]

    # Create templates with varying levels of information
    basic_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition",
        "{model} from {year} with {mileage} miles, {price}",
        "Dealer: {dealer}. {year} {model}, {mileage} miles, {price}",
        "Looking at a {year} {model}, {condition} condition, {price}"
    ]
    
    intermediate_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition, {owner}",
        "{model} ({year}), {mileage} miles, {price}, {usage}, {accident}",
        "Found a {year} {model}, {condition} condition, {price}, {owner}, {accident}",
        "{year} {model}, {mileage} miles, {price}, {usage}, dealer: {dealer}"
    ]
    
    full_info_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition, {owner}, {accident}, {usage}",
        "Dealer: {dealer}. {year} {model}, {mileage} miles, {price}, {condition}, {owner}, {usage}, {accident}",
        "Complete info: {year} {model}, {mileage} miles, {price}, {condition}, {owner}, {accident}, {usage}, dealer: {dealer}"
    ]

    # Combine all templates
    all_templates = basic_templates + intermediate_templates + full_info_templates

    # Generate 100 diverse test queries with varying information completeness
    test_queries = []
    for _ in range(100):
        template = random.choice(all_templates)
        
        # For basic templates, don't include all optional features
        if template in basic_templates:
            query = template.format(
                year=random.choice(years),
                model=random.choice(sample_models),
                mileage=random.choice(mileages),
                price=random.choice(prices),
                condition=random.choice(conditions),
                dealer=random.choice(dealers)
            )
        else:
            query = template.format(
                year=random.choice(years),
                model=random.choice(sample_models),
                mileage=random.choice(mileages),
                price=random.choice(prices),
                condition=random.choice(conditions),
                dealer=random.choice(dealers),
                accident=random.choice(accident_options),
                owner=random.choice(owner_options),
                usage=random.choice(usage_options)
            )
        test_queries.append(query)

    # Add some manual examples that cover edge cases
    test_queries.extend([
        "2021 Toyota Camry with 35,000 miles for $25,000 in used condition from AutoNation, no accidents, 1 owner",
        "2019 Honda Accord, 75,000 miles, $18,500, used condition, personal use",
        "Tesla Model 3 2022 with 12,000 miles priced at $42,000, clean history",
        "Ford F-150 2017, 120,000 miles, $22,999, used condition, commercial use, accident reported",
        "2018 Nissan Rogue, $16,500, 85,000 miles, used condition, 3 owners",
        "2018 Subaru Baja, $500 per month, 2,000 miles, used condition, 1 owner",
        "2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history"
    ])
    
    min_score = 1000 # Will store smallest tuple query
    min_query = ""

    # Test the predictor with sample queries
    for i, query in enumerate(test_queries):  # Just test first 10 for demonstration
        try:
            score = predictor.predict_score(query)

            if (score < min_score) and (query != ""):
                min_score = score
                min_query = query
            
            print(f"Query {i+1}: {query}")
            print(f"Predicted Score: {score:.2f}\n")
        except Exception as e:
            print(f"Error processing query: {query}")
            print(f"Error: {str(e)}\n")
    
    print(f"Min Query: {min_query}")
    print(f"Min Score: {min_score:.2f}\n")
# Out:
# Extracted car info: {'Year': 2017, 'Model': 'Mini Countryman', 'Mileage': None, 'Price': 48000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 1: Found a 2017 MINI Countryman Cooper S ALL4, New condition, $48,000, single owner, 1 accident
# Predicted Score: 52.67
#
# Extracted car info: {'Year': 2022, 'Model': 'Dodge Viper', 'Mileage': None, 'Price': 120000, 'Condition': 'New', 'Dealer': 'a 2022 Dodge Viper ACR, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 2: Looking at a 2022 Dodge Viper ACR, New condition, $120,000
# Predicted Score: 64.74
#
# Extracted car info: {'Year': 2000, 'Model': 'Audi S6', 'Mileage': 225000, 'Price': 24000, 'Condition': None, 'Dealer': 'Land Rover Jaguar Naperville', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 3: Complete info: 2000 Audi S6 Premium Plus, 225,000 miles, $24,000, Other, 4+ owners, no accidents, personal use, dealer: Land Rover Jaguar Naperville
# Predicted Score: 57.16
#
# Extracted car info: {'Year': 2020, 'Model': 'Ford Explorer', 'Mileage': 55000, 'Price': 12000, 'Condition': None, 'Dealer': 'Ford Explorer Limited', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 4: 2020 Ford Explorer Limited, 55,000 miles, $12,000, Other condition, one previous owner, 1 accident, business use
# Predicted Score: 45.05
#
# Extracted car info: {'Year': 2002, 'Model': 'Chevrolet Corvette', 'Mileage': 230000, 'Price': 84000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 5: 2002 Chevrolet Corvette Stingray 1LT, 230,000 miles, $84,000, Used condition, single owner
# Predicted Score: 64.78
#
# Extracted car info: {'Year': 1999, 'Model': 'Bmw Alpina B7', 'Mileage': 15000, 'Price': 46000, 'Condition': 'Used', 'Dealer': 'Autohaus', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 6: Complete info: 1999 BMW ALPINA B7 xDrive, 15,000 miles, $46,000, Used, 4+ owners, accident reported, personal use, dealer: Autohaus on Edens
# Predicted Score: 54.16
#
# Extracted car info: {'Year': 2010, 'Model': 'Audi Q3', 'Mileage': 190000, 'Price': 104000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 7: 2010 Audi Q3 45 S line Premium Plus, 190,000 miles, $104,000, Certified condition
# Predicted Score: 67.47
#
# Extracted car info: {'Year': 2017, 'Model': 'Ford Escape', 'Mileage': 185000, 'Price': 114000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 8: Ford Escape PHEV (2017), 185,000 miles, $114,000, business use, accident history
# Predicted Score: 78.33
#
# Extracted car info: {'Year': 1998, 'Model': 'Jeep Wrangler', 'Mileage': None, 'Price': 44000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 9: Found a 1998 Jeep Wrangler Unlimited Sport, Used condition, $44,000, single owner, accident history
# Predicted Score: 52.93
#
# Extracted car info: {'Year': 2011, 'Model': 'Honda Pilot', 'Mileage': 210000, 'Price': 16000, 'Condition': None, 'Dealer': 'G Motors', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 10: Dealer: G Motors. 2011 Honda Pilot Special Edition, 210,000 miles, $16,000, Other, 1 owner, personal use, accident history
# Predicted Score: 52.67
#
# Extracted car info: {'Year': 2020, 'Model': 'Land Rover Range Rover', 'Mileage': 175000, 'Price': 98000, 'Condition': None, 'Dealer': 'CarMax Costa Mesa', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 11: Complete info: 2020 Land Rover Range Rover 5.0L Supercharged Autobiography, 175,000 miles, $98,000, Other, 4+ owners, accident history, private use, dealer: CarMax Costa Mesa
# Predicted Score: 74.90
#
# Extracted car info: {'Year': 2016, 'Model': 'Bentley Continental', 'Mileage': None, 'Price': 84000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 12: Found a 2016 Bentley Continental GT Mulliner V8, Certified condition, $84,000, single owner, accident history
# Predicted Score: 65.18
#
# Extracted car info: {'Year': 2010, 'Model': 'Cadillac Escalade', 'Mileage': 75000, 'Price': 74000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 13: Cadillac Escalade Sport from 2010 with 75,000 miles, $74,000
# Predicted Score: 54.08
#
# Extracted car info: {'Year': 2016, 'Model': 'Land Rover Defender', 'Mileage': 5000, 'Price': 34000, 'Condition': None, 'Dealer': '##eed Motor Cars', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 14: Dealer: Guaranteed Motor Cars. 2016 Land Rover Defender 130 P400 X-Dynamic SE, 5,000 miles, $34,000
# Predicted Score: 39.08
#
# Extracted car info: {'Year': 2017, 'Model': 'Mclaren 765Lt', 'Mileage': 200000, 'Price': 4000, 'Condition': None, 'Dealer': 'McLaren', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 15: 2017 McLaren 765LT Coupe, 200,000 miles, $4,000, Other condition
# Predicted Score: 39.93
#
# Extracted car info: {'Year': 2020, 'Model': 'Aston Martin Dbs', 'Mileage': 75000, 'Price': 82000, 'Condition': None, 'Dealer': 'CarMax Oklahoma', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 16: Dealer: CarMax Oklahoma City. 2020 Aston Martin DBS ULTIMATE 770, 75,000 miles, $82,000
# Predicted Score: 55.56
#
# Extracted car info: {'Year': 2013, 'Model': 'Mclaren 765Lt', 'Mileage': 35000, 'Price': 108000, 'Condition': None, 'Dealer': 'CarMax Vancouver', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 17: Dealer: CarMax Vancouver. 2013 McLaren 765LT Coupe, 35,000 miles, $108,000
# Predicted Score: 62.83
#
# Extracted car info: {'Year': 2001, 'Model': 'Chevrolet Corvette', 'Mileage': None, 'Price': 76000, 'Condition': 'New', 'Dealer': 'a 2001 Chevrolet Corvette Stingray w', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 18: Looking at a 2001 Chevrolet Corvette Stingray w/3LT, New condition, $76,000
# Predicted Score: 52.70
#
# Extracted car info: {'Year': 2019, 'Model': 'Nissan Altima', 'Mileage': None, 'Price': 72000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 1}
# Query 19: Found a 2019 Nissan Altima SV, Used condition, $72,000, 3 owners, clean history
# Predicted Score: 58.45
#
# Extracted car info: {'Year': 2017, 'Model': 'Ford E150', 'Mileage': 85000, 'Price': 102000, 'Condition': None, 'Dealer': 'CarMax Lexington', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 20: Dealer: CarMax Lexington. 2017 Ford E150 XL, 85,000 miles, $102,000
# Predicted Score: 62.81
#
# Extracted car info: {'Year': 1998, 'Model': 'Acura Rdx', 'Mileage': None, 'Price': 64000, 'Condition': 'Certified', 'Dealer': 'a 1998 Acura RDX Base, Certified condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 21: Looking at a 1998 Acura RDX Base, Certified condition, $64,000
# Predicted Score: 49.41
#
# Extracted car info: {'Year': 2007, 'Model': 'Chevrolet Trax', 'Mileage': 245000, 'Price': 96000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 22: Chevrolet Trax LT (2007), 245,000 miles, $96,000, fleet use, accident reported
# Predicted Score: 76.26
#
# Extracted car info: {'Year': 2010, 'Model': 'Mercedes - Benz CLS', 'Mileage': 70000, 'Price': 56000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 23: Mercedes-Benz CLS 450 Base from 2010 with 70,000 miles, $56,000
# Predicted Score: 48.49
#
# Extracted car info: {'Year': 2007, 'Model': 'Dodge Jeep', 'Mileage': 45000, 'Price': 30000, 'Condition': None, 'Dealer': 'RAM', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 24: 2007 DeTomaso Pantera, 45,000 miles, $30,000, business use, dealer: Jack Phelan Chrysler Dodge Jeep RAM
# Predicted Score: 40.23
#
# Extracted car info: {'Year': 2009, 'Model': 'Audi A5', 'Mileage': 120000, 'Price': 20000, 'Condition': None, 'Dealer': '##dier', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 25: 2009 Audi A5 Sportback 45 S Line Premium Plus, 120,000 miles, $20,000, commercial use, dealer: Knauz Ineos Grenadier of Lake Bluff
# Predicted Score: 40.37
#
# Extracted car info: {'Year': 2016, 'Model': 'Buick Enclave', 'Mileage': 115000, 'Price': 50000, 'Condition': None, 'Dealer': '##uick Enclave Avenir AWD', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 26: 2016 Buick Enclave Avenir AWD, 115,000 miles, $50,000, Other condition
# Predicted Score: 47.97
#
# Extracted car info: {'Year': 2018, 'Model': 'Infiniti Ex35', 'Mileage': 115000, 'Price': 60000, 'Condition': None, 'Dealer': 'INFINITI', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 27: INFINITI EX35 Journey AWD 4dr Crossover (2018), 115,000 miles, $60,000, fleet use, accident reported
# Predicted Score: 61.58
#
# Extracted car info: {'Year': 2014, 'Model': 'Ford Escape', 'Mileage': 110000, 'Price': 74000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 28: 2014 Ford Escape ST-Line Select, 110,000 miles, $74,000, Certified condition
# Predicted Score: 54.95
#
# Extracted car info: {'Year': 2008, 'Model': 'Nissan Altima', 'Mileage': 215000, 'Price': 32000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 29: 2008 Nissan Altima SR, 215,000 miles, $32,000, Other condition
# Predicted Score: 47.44
#
# Extracted car info: {'Year': 2020, 'Model': 'Toyota Yaris', 'Mileage': 135000, 'Price': 106000, 'Condition': 'New', 'Dealer': 'CarMax Greenville', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 30: Complete info: 2020 Toyota Yaris LE, 135,000 miles, $106,000, New, 1 owner, clean history, commercial use, dealer: CarMax Greenville
# Predicted Score: 65.84
#
# Extracted car info: {'Year': 2002, 'Model': 'Gmc Sierra 1500', 'Mileage': 160000, 'Price': 24000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 31: 2002 GMC Sierra 1500 Denali, 160,000 miles, $24,000, New condition
# Predicted Score: 43.77
#
# Extracted car info: {'Year': 2008, 'Model': 'Toyota 4Runner', 'Mileage': 180000, 'Price': 110000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 32: Toyota 4Runner SR5 (2008), 180,000 miles, $110,000, personal use, accident reported
# Predicted Score: 77.64
#
# Extracted car info: {'Year': 2022, 'Model': 'Chevrolet Spark', 'Mileage': None, 'Price': 114000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 33: Found a 2022 Chevrolet Spark EV LT, Certified condition, $114,000, one previous owner, no accidents
# Predicted Score: 74.38
#
# Extracted car info: {'Year': 2000, 'Model': 'Lexus Es 350', 'Mileage': None, 'Price': 12000, 'Condition': 'Used', 'Dealer': 'a 2000 Lexus ES 350 Crafted Line, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 34: Looking at a 2000 Lexus ES 350 Crafted Line, Used condition, $12,000
# Predicted Score: 35.63
#
# Extracted car info: {'Year': 2017, 'Model': 'Cadillac Ct4', 'Mileage': 150000, 'Price': 28000, 'Condition': None, 'Dealer': "AutoNation Honda O ' Hare", 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 35: Dealer: AutoNation Honda O'Hare. 2017 Cadillac CT4-V V-Series Blackwing, 150,000 miles, $28,000
# Predicted Score: 42.85
#
# Extracted car info: {'Year': 2018, 'Model': 'Ferrari F40', 'Mileage': 55000, 'Price': 46000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 36: 2018 Ferrari F40 F40, 55,000 miles, $46,000, Other condition
# Predicted Score: 44.33
#
# Extracted car info: {'Year': 2001, 'Model': 'Chevrolet Corvette', 'Mileage': 155000, 'Price': 98000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 37: 2001 Chevrolet Corvette Grand Sport, 155,000 miles, $98,000, Certified condition, one previous owner, accident history, commercial use
# Predicted Score: 75.14
#
# Extracted car info: {'Year': 2008, 'Model': 'Jeep Gladiator', 'Mileage': 130000, 'Price': 52000, 'Condition': None, 'Dealer': 'McGrath Lexus', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 38: Dealer: McGrath Lexus of Westmont. 2008 Jeep Gladiator Overland, 130,000 miles, $52,000
# Predicted Score: 49.93
#
# Extracted car info: {'Year': 2020, 'Model': 'Lexus Ux 250H', 'Mileage': None, 'Price': 60000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 1}
# Query 39: Found a 2020 Lexus UX 250h F SPORT Design, Used condition, $60,000, 3 owners, accident reported
# Predicted Score: 67.46
#
# Extracted car info: {'Year': 1999, 'Model': 'Lincoln Aviator', 'Mileage': 30000, 'Price': 8000, 'Condition': None, 'Dealer': 'Lincoln Aviator Reserve A', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 40: Lincoln Aviator Reserve AWD (1999), 30,000 miles, $8,000, business use, clean history
# Predicted Score: 36.10
#
# Extracted car info: {'Year': 2009, 'Model': 'Mercedes - Benz AMG GT', 'Mileage': 70000, 'Price': 98000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 41: 2009 Mercedes-Benz AMG GT 53 4-Door, 70,000 miles, $98,000, Other condition, one previous owner
# Predicted Score: 61.56
#
# Extracted car info: {'Year': 2005, 'Model': 'Volkswagen Atlas', 'Mileage': 140000, 'Price': 14000, 'Condition': None, 'Dealer': '##ton', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 42: Dealer: Napleton's Palatine Subaru. 2005 Volkswagen Atlas Cross Sport 2.0T SE w/Technology 4MOTION, 140,000 miles, $14,000
# Predicted Score: 40.09
#
# Extracted car info: {'Year': 2012, 'Model': 'Chrysler 300', 'Mileage': 105000, 'Price': 84000, 'Condition': None, 'Dealer': 'Chrysler', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 43: Chrysler 300 S from 2012 with 105,000 miles, $84,000
# Predicted Score: 58.15
#
# Extracted car info: {'Year': 2007, 'Model': 'Maserati Grecale', 'Mileage': 70000, 'Price': 4000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 44: 2007 Maserati Grecale Folgore, 70,000 miles, $4,000, Other condition, 4+ owners, 1 accident, business use
# Predicted Score: 44.10
#
# Extracted car info: {'Year': 2013, 'Model': 'Gmc Savana 2500', 'Mileage': 125000, 'Price': 24000, 'Condition': 'New', 'Dealer': 'Dodge Chrysler Jeep', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 45: Complete info: 2013 GMC Savana 2500 Work Van, 125,000 miles, $24,000, New, one previous owner, accident reported, private use, dealer: Larry Roesch Dodge Chrysler Jeep RAM
# Predicted Score: 50.58
#
# Extracted car info: {'Year': 2000, 'Model': 'Sportback S', 'Mileage': 15000, 'Price': 52000, 'Condition': None, 'Dealer': 'Audi', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 46: Dealer: Perillo BMW. 2000 Audi e-tron Sportback S line Prestige, 15,000 miles, $52,000
# Predicted Score: 46.17
#
# Extracted car info: {'Year': 2005, 'Model': 'Lexus Rx 350L', 'Mileage': 30000, 'Price': 116000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 47: Lexus RX 350L Premium (2005), 30,000 miles, $116,000, commercial use, accident history
# Predicted Score: 75.54
#
# Extracted car info: {'Year': 2010, 'Model': 'Toyota Celica', 'Mileage': 140000, 'Price': 8000, 'Condition': None, 'Dealer': 'Phillips Chevrolet', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 48: Dealer: Phillips Chevrolet of Lansing. 2010 Toyota Celica SS3 5 SPEED MANUAL, 140,000 miles, $8,000
# Predicted Score: 38.86
#
# Extracted car info: {'Year': 2006, 'Model': 'Nissan Pathfinder', 'Mileage': 90000, 'Price': 112000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 49: 2006 Nissan Pathfinder SL, 90,000 miles, $112,000, Used condition
# Predicted Score: 66.45
#
# Extracted car info: {'Year': 2007, 'Model': '##YPE', 'Mileage': 115000, 'Price': 86000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 50: 2007 Jaguar F-TYPE First Edition P300 RWD Automatic, 115,000 miles, $86,000, Used condition, 1 owner, no accidents, personal use
# Predicted Score: 70.62
#
# Extracted car info: {'Year': 2017, 'Model': 'Hyundai Elantra', 'Mileage': None, 'Price': 84000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 51: Found a 2017 Hyundai Elantra SEL Sport, Certified condition, $84,000, 2 owners, accident reported
# Predicted Score: 70.04
#
# Extracted car info: {'Year': 2003, 'Model': 'Bmw 330', 'Mileage': 30000, 'Price': 82000, 'Condition': 'Used', 'Dealer': 'Volkswagen of Oak Lawn', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 52: Dealer: Volkswagen of Oak Lawn. 2003 BMW 330 i xDrive, 30,000 miles, $82,000, Used, 4+ owners, personal use, clean history
# Predicted Score: 55.51
#
# Extracted car info: {'Year': 2007, 'Model': 'Acura Integra', 'Mileage': 145000, 'Price': 106000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 53: 2007 Acura Integra A-Spec Tech Package, 145,000 miles, $106,000, Certified condition
# Predicted Score: 66.66
#
# Extracted car info: {'Year': 2011, 'Model': 'Chevrolet Silverado 1500', 'Mileage': 140000, 'Price': 82000, 'Condition': 'Certified', 'Dealer': 'Bose Motors', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 54: Dealer: Bose Motors. 2011 Chevrolet Silverado 1500 Work Truck, 140,000 miles, $82,000, Certified, 2 owners, private use, 1 accident
# Predicted Score: 73.97
#
# Extracted car info: {'Year': 2015, 'Model': 'Bmw I5', 'Mileage': 250000, 'Price': 64000, 'Condition': None, 'Dealer': 'McGrath Acura', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 0}
# Query 55: Complete info: 2015 BMW i5 eDrive40, 250,000 miles, $64,000, Other, 3 owners, clean history, business use, dealer: McGrath Acura of Morton Grove
# Predicted Score: 65.97
#
# Extracted car info: {'Year': 2021, 'Model': 'Land Rover Range Rover', 'Mileage': None, 'Price': 8000, 'Condition': 'New', 'Dealer': 'Land Rover Range Rover Evoque SE', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 56: Looking at a 2021 Land Rover Range Rover Evoque SE, New condition, $8,000
# Predicted Score: 34.28
#
# Extracted car info: {'Year': 2009, 'Model': 'Chevrolet Silverado 2500', 'Mileage': 75000, 'Price': 12000, 'Condition': None, 'Dealer': 'Silver', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 57: Chevrolet Silverado 2500 ZR2 from 2009 with 75,000 miles, $12,000
# Predicted Score: 37.47
#
# Extracted car info: {'Year': 2001, 'Model': 'Fiat 500L', 'Mileage': None, 'Price': 44000, 'Condition': None, 'Dealer': 'a 2001 FIAT 500L Easy, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 58: Looking at a 2001 FIAT 500L Easy, Other condition, $44,000
# Predicted Score: 42.98
#
# Extracted car info: {'Year': 2011, 'Model': 'Dodge Durango', 'Mileage': 35000, 'Price': 52000, 'Condition': 'Certified', 'Dealer': 'London Motors Chicago', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 59: Complete info: 2011 Dodge Durango Pursuit, 35,000 miles, $52,000, Certified, 2 owners, 1 accident, personal use, dealer: London Motors Chicago
# Predicted Score: 61.10
#
# Extracted car info: {'Year': 2021, 'Model': 'Acura Tlx', 'Mileage': 95000, 'Price': 100000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 60: 2021 Acura TLX V6 A-Spec, 95,000 miles, $100,000, Other condition
# Predicted Score: 62.45
#
# Extracted car info: {'Year': 2004, 'Model': 'Chevrolet Trailblazer', 'Mileage': 175000, 'Price': 28000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 61: 2004 Chevrolet TrailBlazer EXT LT, 175,000 miles, $28,000, Used condition, 1 owner, clean history, commercial use
# Predicted Score: 45.27
#
# Extracted car info: {'Year': 2019, 'Model': 'Audi Sq8', 'Mileage': 195000, 'Price': 22000, 'Condition': None, 'Dealer': 'Audi', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 62: Audi SQ8 4.0T quattro Premium Plus (2019), 195,000 miles, $22,000, fleet use, 1 accident
# Predicted Score: 53.11
#
# Extracted car info: {'Year': 2022, 'Model': 'Kia Niro', 'Mileage': None, 'Price': 78000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 63: Found a 2022 Kia Niro EV EX, Certified condition, $78,000, 4+ owners, accident reported
# Predicted Score: 62.95
#
# Extracted car info: {'Year': 1999, 'Model': 'Bmw I5', 'Mileage': 200000, 'Price': 28000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 64: 1999 BMW i5 M60, 200,000 miles, $28,000, Certified condition
# Predicted Score: 47.04
#
# Extracted car info: {'Year': 2006, 'Model': 'Audi A5', 'Mileage': None, 'Price': 98000, 'Condition': 'New', 'Dealer': 'a 2006 Audi A5 Sportback 45 S Line Premium Plus, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 65: Looking at a 2006 Audi A5 Sportback 45 S Line Premium Plus, New condition, $98,000
# Predicted Score: 58.87
#
# Extracted car info: {'Year': 2016, 'Model': 'Ferrari 360 Modena', 'Mileage': 95000, 'Price': 118000, 'Condition': None, 'Dealer': 'CarMax Wichita', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 66: Dealer: CarMax Wichita. 2016 Ferrari 360 Modena Berlinetta F1, 95,000 miles, $118,000
# Predicted Score: 67.51
#
# Extracted car info: {'Year': 2017, 'Model': 'Bmw 650', 'Mileage': 45000, 'Price': 38000, 'Condition': 'New', 'Dealer': 'Silver Auto Sales Inc', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 67: Dealer: Silver Auto Sales Inc.. 2017 BMW 650 Gran Coupe i, 45,000 miles, $38,000, New, single owner, fleet use, accident reported
# Predicted Score: 51.06
#
# Extracted car info: {'Year': 2018, 'Model': 'Porsche 918 Spyder', 'Mileage': 40000, 'Price': 64000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 68: 2018 Porsche 918 Spyder Weissach Package PTS Grey Black! Extremely RARE 1 of 1 Spec!, 40,000 miles, $64,000, Certified condition, one previous owner
# Predicted Score: 48.95
#
# Extracted car info: {'Year': 2021, 'Model': 'Bmw X6', 'Mileage': 205000, 'Price': 108000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 69: BMW X6 xDrive40i from 2021 with 205,000 miles, $108,000
# Predicted Score: 68.81
#
# Extracted car info: {'Year': 2017, 'Model': 'Mercedes - Benz E - Class', 'Mileage': 190000, 'Price': 72000, 'Condition': None, 'Dealer': 'Volkswagen of Oak', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 70: 2017 Mercedes-Benz E-Class, 190,000 miles, $72,000, personal use, dealer: Volkswagen of Oak Lawn
# Predicted Score: 57.49
#
# Extracted car info: {'Year': 2002, 'Model': 'Chrysler 300', 'Mileage': 50000, 'Price': 10000, 'Condition': None, 'Dealer': 'Chrysler', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 71: 2002 Chrysler 300 S, 50,000 miles, $10,000, Other condition, 1 owner
# Predicted Score: 36.72
#
# Extracted car info: {'Year': 1999, 'Model': 'Chevrolet Silverado 1500', 'Mileage': 130000, 'Price': 112000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 72: 1999 Chevrolet Silverado 1500 LTZ, 130,000 miles, $112,000, Used condition, 1 owner, clean history, personal use
# Predicted Score: 68.22
#
# Extracted car info: {'Year': 2018, 'Model': 'Volkswagen Golf', 'Mileage': 125000, 'Price': 46000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 73: Volkswagen Golf SEL from 2018 with 125,000 miles, $46,000
# Predicted Score: 47.01
#
# Extracted car info: {'Year': 2014, 'Model': 'Jaguar F', 'Mileage': 180000, 'Price': 56000, 'Condition': 'Certified', 'Dealer': 'Chicago Motor Group', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 74: Dealer: Chicago Motor Group. 2014 Jaguar F-TYPE S, 180,000 miles, $56,000, Certified, 1 owner, fleet use, 1 accident
# Predicted Score: 63.18
#
# Extracted car info: {'Year': 2005, 'Model': 'Land Rover Range Rover', 'Mileage': 160000, 'Price': 36000, 'Condition': None, 'Dealer': 'Land', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 75: Dealer: Woodfield Nissan. 2005 Land Rover Range Rover Westminster, 160,000 miles, $36,000, Other, 4+ owners, business use, 1 accident
# Predicted Score: 56.75
#
# Extracted car info: {'Year': 2009, 'Model': 'Toyota Sienna', 'Mileage': 225000, 'Price': 30000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 76: Toyota Sienna XLE 8 Passenger (2009), 225,000 miles, $30,000, personal use, no accidents
# Predicted Score: 57.55
#
# Extracted car info: {'Year': 2009, 'Model': 'Hyundai Tucson', 'Mileage': 5000, 'Price': 114000, 'Condition': 'Used', 'Dealer': 'Tucson', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 77: 2009 Hyundai Tucson SEL, 5,000 miles, $114,000, Used condition
# Predicted Score: 63.49
#
# Extracted car info: {'Year': 2016, 'Model': 'Jeep Grand Cherokee', 'Mileage': 190000, 'Price': 26000, 'Condition': 'Certified', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 0}
# Query 78: 2016 Jeep Grand Cherokee L Overland, 190,000 miles, $26,000, Certified condition, 3 owners, 1 accident, business use
# Predicted Score: 64.35
#
# Extracted car info: {'Year': 2021, 'Model': 'Gmc Terrain', 'Mileage': 155000, 'Price': 54000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 79: 2021 GMC Terrain SLE, 155,000 miles, $54,000, New condition, one previous owner, 1 accident, commercial use
# Predicted Score: 61.11
#
# Extracted car info: {'Year': 2015, 'Model': 'Alfa Romeo Tonale', 'Mileage': 30000, 'Price': 50000, 'Condition': None, 'Dealer': 'MGM Classic Cars', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 80: 2015 Alfa Romeo Tonale AWD, 30,000 miles, $50,000, commercial use, dealer: MGM Classic Cars
# Predicted Score: 44.69
#
# Extracted car info: {'Year': 2010, 'Model': 'Porsche 718 Spyder', 'Mileage': 70000, 'Price': 8000, 'Condition': None, 'Dealer': 'Car City Inc', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 81: 2010 Porsche 718 Spyder, 70,000 miles, $8,000, personal use, dealer: Car City Inc
# Predicted Score: 36.79
#
# Extracted car info: {'Year': 1999, 'Model': 'Ford F - 150 Limited', 'Mileage': None, 'Price': 90000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 82: Found a 1999 Ford F-150 Limited, Used condition, $90,000, 4+ owners, accident reported
# Predicted Score: 68.44
#
# Extracted car info: {'Year': 2019, 'Model': 'Bmw M4', 'Mileage': 125000, 'Price': 36000, 'Condition': 'Used', 'Dealer': 'Oak Lawn Toyota', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 83: Complete info: 2019 BMW M4 Competition xDrive, 125,000 miles, $36,000, Used, 2 owners, accident history, personal use, dealer: Oak Lawn Toyota
# Predicted Score: 59.22
#
# Extracted car info: {'Year': 2022, 'Model': 'Lexus Lc 500H', 'Mileage': 20000, 'Price': 10000, 'Condition': 'Certified', 'Dealer': 'Ultimo Motors North Shore', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 84: Dealer: Ultimo Motors North Shore. 2022 Lexus LC 500h Base, 20,000 miles, $10,000, Certified, one previous owner, personal use, accident history
# Predicted Score: 44.10
#
# Extracted car info: {'Year': 2005, 'Model': 'Gmc Acadia', 'Mileage': 230000, 'Price': 4000, 'Condition': None, 'Dealer': 'Castle Chrysler Dodge Jeep Ram', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 85: Dealer: Castle Chrysler Dodge Jeep Ram of Naperville. 2005 GMC Acadia Denali, 230,000 miles, $4,000
# Predicted Score: 41.56
#
# Extracted car info: {'Year': 2013, 'Model': 'Toyota Tundra', 'Mileage': 5000, 'Price': 80000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 86: 2013 Toyota Tundra Hybrid Platinum, 5,000 miles, $80,000, Other condition
# Predicted Score: 52.77
#
# Extracted car info: {'Year': 2016, 'Model': 'Volvo Xc60', 'Mileage': 75000, 'Price': 82000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 87: 2016 Volvo XC60 B6 Ultimate Bright Theme, 75,000 miles, $82,000, Other condition
# Predicted Score: 55.90
#
# Extracted car info: {'Year': 2000, 'Model': 'Audi Q5', 'Mileage': None, 'Price': 78000, 'Condition': None, 'Dealer': 'a 2000 Audi Q5 55 S line Premium, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 88: Looking at a 2000 Audi Q5 55 S line Premium, Other condition, $78,000
# Predicted Score: 53.39
#
# Extracted car info: {'Year': 2022, 'Model': 'Bmw 740', 'Mileage': 200000, 'Price': 50000, 'Condition': None, 'Dealer': 'Team Toyota', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 89: 2022 BMW 740 i xDrive, 200,000 miles, $50,000, business use, dealer: Team Toyota
# Predicted Score: 50.76
#
# Extracted car info: {'Year': 2020, 'Model': 'Mercedes - Benz AMG GT AMG GT S', 'Mileage': 125000, 'Price': 18000, 'Condition': None, 'Dealer': 'Royce', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 90: Dealer: Bentley Bugatti Lamborghini Maserati Rolls-Royce of Chicago. 2020 Mercedes-Benz AMG GT AMG GT S, 125,000 miles, $18,000
# Predicted Score: 39.53
#
# Extracted car info: {'Year': 2005, 'Model': 'Dodge Sprinter', 'Mileage': 15000, 'Price': 22000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 91: Dodge Sprinter 2500 from 2005 with 15,000 miles, $22,000
# Predicted Score: 37.23
#
# Extracted car info: {'Year': 2002, 'Model': 'Pre', 'Mileage': 0, 'Price': 12000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 92: 2002 Mazda CX-90 3.3 Turbo Premium, 0 miles, $12,000, Other condition, single owner
# Predicted Score: 35.54
#
# Extracted car info: {'Year': 2002, 'Model': 'Ferrari Portofino', 'Mileage': 240000, 'Price': 18000, 'Condition': 'New', 'Dealer': 'Family Hyundai', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 0}
# Query 93: Complete info: 2002 Ferrari Portofino Base, 240,000 miles, $18,000, New, 2 owners, no accidents, business use, dealer: Family Hyundai
# Predicted Score: 60.15
#
# Extracted car info: {'Year': 2015, 'Model': 'Land Rover Range Rover', 'Mileage': 180000, 'Price': 62000, 'Condition': 'Used', 'Dealer': 'Land Rover Range Rover', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 94: 2015 Land Rover Range Rover Autobiography, 180,000 miles, $62,000, Used condition
# Predicted Score: 54.03
#
# Extracted car info: {'Year': 2022, 'Model': 'Alfa Romeo Tonale', 'Mileage': 70000, 'Price': 64000, 'Condition': None, 'Dealer': 'Alfa Romeo Tonale Veloce', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 95: Alfa Romeo Tonale Veloce from 2022 with 70,000 miles, $64,000
# Predicted Score: 49.80
#
# Extracted car info: {'Year': 1999, 'Model': 'Lexus Gx 460', 'Mileage': None, 'Price': 6000, 'Condition': 'Used', 'Dealer': 'a 1999 Lexus GX 460 Luxury, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 96: Looking at a 1999 Lexus GX 460 Luxury, Used condition, $6,000
# Predicted Score: 34.95
#
# Extracted car info: {'Year': 2015, 'Model': 'Bmw X5', 'Mileage': 5000, 'Price': 36000, 'Condition': None, 'Dealer': 'CarMax', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 97: Dealer: CarMax LAX. 2015 BMW X5 xDrive50i, 5,000 miles, $36,000
# Predicted Score: 39.67
#
# Extracted car info: {'Year': 2003, 'Model': 'Toyota 4Runner', 'Mileage': 45000, 'Price': 24000, 'Condition': None, 'Dealer': 'Schaumburg', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 98: Dealer: Napleton's Schaumburg Subaru. 2003 Toyota 4Runner SR5 Premium, 45,000 miles, $24,000
# Predicted Score: 39.02
#
# Extracted car info: {'Year': 2022, 'Model': 'Tesla Model X', 'Mileage': 90000, 'Price': 76000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 99: Tesla Model X Performance from 2022 with 90,000 miles, $76,000
# Predicted Score: 54.21
#
# Extracted car info: {'Year': 2017, 'Model': 'Audi Rs 3', 'Mileage': 250000, 'Price': 86000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 100: 2017 Audi RS 3 2.5T, 250,000 miles, $86,000, New condition
# Predicted Score: 64.56
#
# Extracted car info: {'Year': 2021, 'Model': 'Toyota Camry', 'Mileage': 35000, 'Price': 25000, 'Condition': 'Used', 'Dealer': 'AutoNation', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 101: 2021 Toyota Camry with 35,000 miles for $25,000 in used condition from AutoNation, no accidents, 1 owner
# Predicted Score: 46.92
#
# Extracted car info: {'Year': 2019, 'Model': 'Honda Accord', 'Mileage': 75000, 'Price': 18500, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 102: 2019 Honda Accord, 75,000 miles, $18,500, used condition, personal use
# Predicted Score: 38.01
#
# Extracted car info: {'Year': 2022, 'Model': 'Tesla Model 3', 'Mileage': 12000, 'Price': 42000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 103: Tesla Model 3 2022 with 12,000 miles priced at $42,000, clean history
# Predicted Score: 41.09
#
# Extracted car info: {'Year': 2017, 'Model': 'Ford F - 150', 'Mileage': 120000, 'Price': 22999, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 104: Ford F-150 2017, 120,000 miles, $22,999, used condition, commercial use, accident reported
# Predicted Score: 49.86
#
# Extracted car info: {'Year': 2018, 'Model': 'Nissan Rogue', 'Mileage': 85000, 'Price': 16500, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 1}
# Query 105: 2018 Nissan Rogue, $16,500, 85,000 miles, used condition, 3 owners
# Predicted Score: 44.68
#
# Extracted car info: {'Year': 2018, 'Model': 'Subaru Baja', 'Mileage': 2000, 'Price': None, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': 500, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 106: 2018 Subaru Baja, $500 per month, 2,000 miles, used condition, 1 owner
# Predicted Score: 37.01
#
# Extracted car info: {'Year': 2022, 'Model': 'Toyota Camry', 'Mileage': 12000, 'Price': 9000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 107: 2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history
# Predicted Score: 34.78
#
# Min Query: Looking at a 2021 Land Rover Range Rover Evoque SE, New condition, $8,000
# Min Score: 34.28
