# %% [markdown]
# Current Model Notebook

# %%
# Create the dataset

import numpy as np
import pandas as pd
from datetime import datetime
import random as rand
from sklearn.feature_selection import SelectPercentile, f_regression
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
import torch
import json
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import joblib
import warnings
from transformers import logging
import joblib

# Ignore specific warnings and logs
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning, module='tqdm')
logging.set_verbosity_error() 

# Read the file
df = pd.read_csv("training_cars_data.csv")

# Make Car Model into two different columns
if 'Car Model' in df.columns:
    df[['Year', 'Model']] = df['Car Model'].str.extract(r'(\d{4})\s(.*)')
    df = df.drop(columns=['Car Model'])

if 'Price (USD)' in df.columns:
    df = df.rename(columns={'Price (USD)': 'Price'})

if 'Dealer Name' in df.columns:
    df = df.rename(columns={'Dealer Name': 'Dealer'})

# Standardize all matching rows to 'Certified'
df['Condition'] = df['Condition'].apply(
    lambda x: 'Certified' if 'certified' in str(x).lower() else x
)
# Clean condition column
df['Condition'] = df['Condition'].replace([
    'Prequalify now', 'stock_type', 'New & Used', np.nan
], 'Other')

# List of columns to clean
columns_to_clean = ['Monthly Payment', 'Mileage', 'Price', 'Year']

# Apply cleaning function to all specified columns
df[columns_to_clean] = df[columns_to_clean].apply(lambda x: x.str.replace(r'\D', '', regex=True))

# Convert to numeric while preserving NaNs
df[columns_to_clean] = df[columns_to_clean].apply(pd.to_numeric, errors='coerce')

# Set empty Mileage values to 0
df['Mileage'] = df['Mileage'].fillna(0)

# Synthetic feature generation
def random_accident(row):
    return rand.choices([1, 0], weights=[30, 70], k=1)[0]  # 1 = accident, 0 = no accident

def random_owners(row):
    numbers = [0, 1, 2, 3, 4]
    weights = [40, 40, 30, 20, 10]
    return rand.choices(numbers, weights=weights, k=1)[0] 

def random_usage(row):
    return rand.choices([1, 0], weights=[80, 20], k=1)[0]  # 1 = personal use, 0 = not personal

# Apply the random features
df['Accidents'] = df.apply(random_accident, axis=1)
df['Owners'] = df.apply(random_owners, axis=1)
df['Usage'] = df.apply(random_usage, axis=1) 

# Feature engineering
current_year = datetime.now().year
df['Age'] = current_year - df['Year']
df['MilesPerYear'] = df['Mileage'] / (df['Age'] + 1)
df['PricePerMile'] = df['Price'] / (df['Mileage'] + 1)

# Hot-one encoding
df = pd.get_dummies(df, columns=['Condition', 'Model', 'Dealer'], drop_first=False)

# def simple_scoring(row):
#     if pd.isna(row['Mileage']) or pd.isna(row['Price']) or pd.isna(row['Year']):
#         return np.nan
    
#     age = current_year - row['Year']
#     price_score = row['Price'] / 2000  
#     mileage_score = row['Mileage'] / 2500    
#     age_score = age * 5                     
    
#     weighted_sum = (0.5 * price_score) + (0.4 * mileage_score) + (0.1 * age_score)
    
#     if row['Accidents'] == 1:
#         weighted_sum += 15  
    
#     if row['Owners'] == 2:
#         weighted_sum += 5
#     elif row['Owners'] > 2:
#         weighted_sum += 10
    
#     if row['Usage'] == 0:  # Commercial usage penalty
#         weighted_sum += 10
    
#     return weighted_sum

 
# df['Score'] = df.apply(simple_scoring, axis=1)

MEDIAN_PRICE = 25000  # median price baseline
MAX_MILEAGE = 250000
MAX_AGE = 30

def enhanced_scoring(row):
    # Check essential columns early
    if pd.isna(row.get('Mileage')) or pd.isna(row.get('Year')):
        return np.nan

    age = current_year - row['Year']
    if age < 0:
        age = 0  # avoid negative age if year is in future

    # Determine price_for_score
    price = row.get('Price')
    monthly_payment = row.get('Monthly Payment')

    if not pd.isna(price):
        price_for_score = price
    elif not pd.isna(monthly_payment):
        price_for_score = monthly_payment * 60  # estimate full price (5 years)
    else:
        return np.nan  # no price info at all

    # Normalize and clamp values
    clamped_mileage = min(row['Mileage'], MAX_MILEAGE)
    clamped_age = min(age, MAX_AGE)

    # Scores (log scale for price, power scale for others)
    price_score = np.log1p(price_for_score / MEDIAN_PRICE) * 100
    mileage_score = 100 * ((clamped_mileage / MAX_MILEAGE) ** 0.8)
    age_score = 100 * ((clamped_age / MAX_AGE) ** 0.7)

    weighted_sum = (0.55 * price_score) + (0.35 * mileage_score) + (0.10 * age_score)

    # Condition adjustment
    condition_new = row.get('Condition_New', 0) == 1
    condition_certified = row.get('Condition_Certified', 0) == 1
    condition_used = row.get('Condition_Used', 0) == 1

    if condition_new:
        weighted_sum -= 20
    elif condition_certified:
        weighted_sum -= 15
    elif not condition_used:
        weighted_sum += 5  # penalty for unknown condition

    # Accidents adjustment
    accidents = row.get('Accidents', 0)
    if accidents == 1:
        weighted_sum += 10
    elif accidents > 1:
        weighted_sum += 15  # harsher penalty for multiple accidents

    # Owners adjustment (penalties scale moderately)
    owners = row.get('Owners', 1)  # default 1 if missing
    if owners == 2:
        weighted_sum += 8
    elif owners > 2:
        weighted_sum += 8 + 3 * (owners - 2)  # scaled penalty

    # Usage adjustment
    usage = row.get('Usage', 1)  # assume 1 = non-commercial, 0 = commercial
    if usage == 0:
        # More penalty for commercial, scales with age
        weighted_sum += 15 * (1 + clamped_age / MAX_AGE)

    # Mileage per year adjustment
    years_used = age if age > 0 else 1
    miles_per_year = row['Mileage'] / years_used

    if miles_per_year < 7500:
        weighted_sum -= 5  # low mileage is good
    elif miles_per_year > 15000:
        weighted_sum += 10  # high mileage is bad

    return weighted_sum

# Apply to dataframe
df['Score'] = df.apply(enhanced_scoring, axis=1)

# Create training and testing data
df = df.dropna(subset=['Monthly Payment', 'Mileage', 'Price', 'Year', 'Score'])

X = df.drop(columns=['Score'])
y = df['Score']

# Feature selection (keep features with top 10% relevance = drop bottom 90%)
selector = SelectPercentile(f_regression, percentile=50)
X_selected = selector.fit_transform(X, y)

# Get selected feature names
selected_features = [X.columns[i] for i in selector.get_support(indices=True)]
print(f"Selected {len(selected_features)} features:")
print(selected_features)

# Update feature list
model_features = selected_features
with open('model_features.json', 'w') as f:
    json.dump(model_features, f)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_selected)

joblib.dump(scaler, 'scaler.pkl')

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y.values.reshape(-1, 1), test_size=0.2, random_state=42)

# Save X_train values
X_train_df = pd.DataFrame(X_train, columns=model_features)
X_train_df.to_pickle("X_train.pkl")

# XGBoost Benchmarking
print("\nXGBoost Benchmark:")
xgb = XGBRegressor(n_estimators=1000, learning_rate=0.01, early_stopping_rounds=50, random_state=42)
xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)

xgb_pred = xgb.predict(X_test)
xgb_mse = mean_squared_error(y_test, xgb_pred)
xgb_r2 = r2_score(y_test, xgb_pred)
xgb_mae = mean_absolute_error(y_test, xgb_pred)

print(f"XGBoost MSE: {xgb_mse:.2f}")
print(f"XGBoost R²: {xgb_r2:.4f}")
print(f"XGBoost MAE: {xgb_mae:.2f}")

# Scale target
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

joblib.dump(y_scaler, 'model_scaler.pkl')

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_scaled.reshape(-1, 1), dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_scaled.reshape(-1, 1), dtype=torch.float32)

# Neural Network Implementation

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("\nUsing device:", device)

# Dataset Setup
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Model Definition
class ImprovedMLP(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.2),
            nn.Linear(64, 1)
        )
    
    def forward(self, x):
        return self.net(x)

# Training with Early Stopping
model = ImprovedMLP(X_train.shape[1]).to(device)
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

best_loss = float('inf')
patience = 100
no_improve = 0

for epoch in range(200):
    model.train()
    running_loss = 0.0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        running_loss += loss.item() * batch_X.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    
    # Validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs = model(batch_X)
            val_loss += criterion(outputs, batch_y).item() * batch_X.size(0)
    
    val_loss /= len(test_loader.dataset)
    
    if val_loss < best_loss:
        best_loss = val_loss
        no_improve = 0
        torch.save(model.state_dict(), 'best_car_model.pth')

    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
    
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}: Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}")

# Load best model
model.load_state_dict(torch.load('best_car_model.pth'))
y_scaler = joblib.load('model_scaler.pkl')

# Evaluation
model.eval()
all_preds, all_targets = [], []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        outputs = model(batch_X)
        all_preds.append(outputs.cpu())
        all_targets.append(batch_y.cpu())

predictions = torch.cat(all_preds).numpy()
targets = torch.cat(all_targets).numpy()

preds_rescaled = y_scaler.inverse_transform(predictions)
y_true_rescaled = y_scaler.inverse_transform(targets)

print("All predictions (rescaled):")
print(preds_rescaled.flatten())


mse = mean_squared_error(y_true_rescaled, preds_rescaled)
r2 = r2_score(y_true_rescaled, preds_rescaled)
mae = mean_absolute_error(y_true_rescaled, preds_rescaled)

tolerance = 5
within_tolerance = np.abs(y_true_rescaled - preds_rescaled) <= tolerance
accuracy = np.mean(within_tolerance) * 100

print("\nFinal Evaluation:")
print(f"Test MSE: {mse:.2f}")
print(f"Test R²: {r2:.4f}")
print(f"Test MAE: {mae:.2f}")
print(f"Accuracy (within ±{tolerance}): {accuracy:.2f}%")
# Out:
# Selected 1718 features:
# ['Mileage', 'Price', 'Monthly Payment', 'Year', 'Accidents', 'Owners', 'Usage', 'Age', 'MilesPerYear', 'PricePerMile', 'Condition_New', 'Condition_Other', 'Condition_Used', 'Model_Acura Integra', 'Model_Acura Integra A-SPEC', 'Model_Acura Integra A-SPEC w/ Technology', 'Model_Acura Integra A-Spec', 'Model_Acura Integra A-Spec Package', 'Model_Acura Integra A-Spec Tech Package', 'Model_Acura Integra A-Spec Technology', 'Model_Acura Integra Base', 'Model_Acura Integra Type S', 'Model_Acura Integra W/A-SPEC TECHNOLOGY PACKAGE', 'Model_Acura Integra w/A-Spec Package', 'Model_Acura MDX 3.5L w/Technology Package', 'Model_Acura MDX A-SPEC', 'Model_Acura MDX A-Spec', 'Model_Acura MDX A-Spec Package', 'Model_Acura MDX Advance', 'Model_Acura MDX Sport Hybrid 3.0L w/Advance Package', 'Model_Acura NSX Base', 'Model_Acura NSX T', 'Model_Acura RDX A-Spec', 'Model_Acura RDX A-Spec Package', 'Model_Acura RDX Base', 'Model_Acura RDX SH-AWD', 'Model_Acura RDX Technology Package', 'Model_Acura TL Special Edition', 'Model_Acura TLX A-Spec', 'Model_Acura TLX Base', 'Model_Acura TLX V6 A-Spec', 'Model_Alfa Romeo Stelvio Quadrifoglio', 'Model_Alfa Romeo Tonale AWD', 'Model_Alfa Romeo Tonale Base', 'Model_Alfa Romeo Tonale Ti', 'Model_Alfa Romeo Tonale Veloce', 'Model_Alfa Romeo Tonale Veloce EAWD', 'Model_Am General Hummer Wagon', 'Model_Aston Martin DB12 Coupe', 'Model_Aston Martin DB9 Volante', 'Model_Aston Martin DBS Superleggera', 'Model_Aston Martin DBS ULTIMATE 770', 'Model_Aston Martin DBS Volante', 'Model_Aston Martin DBX 707', 'Model_Aston Martin DBX SUV', 'Model_Aston Martin V12 Vanquish Base', 'Model_Aston Martin Vanquish Volante', 'Model_Aston Martin Vantage AMR PROTOTYPE', 'Model_Aston Martin Vantage Coupe', 'Model_Aston Martin Vantage Roadster', 'Model_Aston Martin Virage Base', 'Model_Audi A3 2.0T Tech Premium', 'Model_Audi A3 Premium', 'Model_Audi A4 2.0T Premium quattro', 'Model_Audi A4 2.0T Technik', 'Model_Audi A4 45 S line Premium Plus', 'Model_Audi A4 allroad Premium Plus', 'Model_Audi A6 45 Premium', 'Model_Audi A8 e L 60', 'Model_Audi Q3 45 S line Premium', 'Model_Audi Q3 45 S line Premium Plus', 'Model_Audi Q3 Premium 45 TFSI S line quattro Tiptronic', 'Model_Audi Q3 S line Premium', 'Model_Audi Q3 S-Line Premium', 'Model_Audi Q5 45 Premium Plus', 'Model_Audi Q5 45 S line Premium', 'Model_Audi Q5 S-Line Prestige', 'Model_Audi Q5 Sportback S-Line Premium Plus', 'Model_Audi Q7 3.0T Premium Plus', 'Model_Audi Q7 3.0T Prestige', 'Model_Audi Q7 45 Premium', 'Model_Audi Q7 45 Premium Plus', 'Model_Audi Q7 55 Premium', 'Model_Audi Q7 55 Premium Plus', 'Model_Audi Q7 55 Prestige', 'Model_Audi Q7 Premium Plus', 'Model_Audi Q8 55 Premium Plus', 'Model_Audi Q8 55 Prestige', 'Model_Audi Q8 Premium Plus', 'Model_Audi Q8 Prestige', 'Model_Audi Q8 e-tron Premium', 'Model_Audi RS 3 2.5T', 'Model_Audi RS 3 TFSI quattro S tronic', 'Model_Audi RS 5', 'Model_Audi RS 5 2.9T', 'Model_Audi RS 7 4.0T Prestige', 'Model_Audi RS 7 4.0T quattro', 'Model_Audi RS Q8 4.0T', 'Model_Audi RS Q8 4.0T quattro', 'Model_Audi RS e-tron GT quattro', 'Model_Audi S e-tron GT Premium Plus', 'Model_Audi S3 2.0T Premium Plus', 'Model_Audi S5 3.0 Premium Plus', 'Model_Audi S5 3.0T Premium Plus', 'Model_Audi S5 Prestige', 'Model_Audi S6 Prestige', 'Model_Audi S6 Prestige TFSI quattro Tiptronic', 'Model_Audi S7 4.0T', 'Model_Audi SQ7 4.0T Premium Plus', 'Model_Audi SQ8 4.0T Premium Plus', 'Model_Audi SQ8 4.0T Prestige', 'Model_Audi SQ8 4.0T quattro Premium Plus', 'Model_Audi SQ8 e-tron Premium Plus', 'Model_Audi TTS 2.0T quattro', 'Model_Audi e-tron GT Premium Plus', 'Model_Audi e-tron GT Prestige', 'Model_Audi e-tron Premium', 'Model_Audi e-tron S Prestige', 'Model_Audi e-tron Sportback Prestige', 'Model_Audi e-tron Sportback S line Prestige', 'Model_BMW 1 Series M Base', 'Model_BMW 228 Gran Coupe I Gran Coupe', 'Model_BMW 320 I', 'Model_BMW 325 325xi AWD 4dr Sedan', 'Model_BMW 325 325xi AWD 4dr Wagon', 'Model_BMW 325 Ci', 'Model_BMW 325 i', 'Model_BMW 328 328xi', 'Model_ ...
#
# XGBoost Benchmark:
# XGBoost MSE: 3.62
# XGBoost R²: 0.9930
# XGBoost MAE: 1.10
#
# Using device: cuda
# Epoch 10: Train Loss: 0.0702, Val Loss: 0.0681
# Epoch 20: Train Loss: 0.0413, Val Loss: 0.0554
# Epoch 30: Train Loss: 0.0329, Val Loss: 0.0442
# Epoch 40: Train Loss: 0.0302, Val Loss: 0.0460
# Epoch 50: Train Loss: 0.0277, Val Loss: 0.0475
# Epoch 60: Train Loss: 0.0246, Val Loss: 0.0469
# Epoch 70: Train Loss: 0.0252, Val Loss: 0.0571
# Epoch 80: Train Loss: 0.0234, Val Loss: 0.0516
# Epoch 90: Train Loss: 0.0231, Val Loss: 0.0476
# Epoch 100: Train Loss: 0.0228, Val Loss: 0.0476
# Epoch 110: Train Loss: 0.0217, Val Loss: 0.0506
# Epoch 120: Train Loss: 0.0210, Val Loss: 0.0473
# Epoch 130: Train Loss: 0.0209, Val Loss: 0.0718
# Epoch 140: Train Loss: 0.0203, Val Loss: 0.0648
# Epoch 150: Train Loss: 0.0195, Val Loss: 0.0614
# Early stopping at epoch 151
# All predictions (rescaled):
# [39.73723  61.824463 53.398365 ... 87.560165 73.72928  79.05506 ]
#
# Final Evaluation:
# Test MSE: 67.01
# Test R²: 0.8695
# Test MAE: 4.91
# Accuracy (within ±5): 69.91%

# %%
# Create the LLM input processor
from transformers import pipeline
import re
import json
import random
import os

# Get base dir of current file
BASE_DIR = os.getcwd()
SCRIPT_DIR = os.path.abspath(os.path.join(BASE_DIR, "..", "scripts"))

class CarScorePredictor:
    def __init__(self):
        
        self.input_scaler = joblib.load('scaler.pkl')
        self.output_scaler = joblib.load('model_scaler.pkl')

        # Load model features
        with open('model_features.json', 'r') as f:
            self.model_features = json.load(f)

        with open(os.path.join(SCRIPT_DIR, 'all_make_model_keys.json'), 'r') as f:
            self.model_slugs = json.load(f)
        
        self.model_types = [slug.replace('_', ' ').replace('-', ' ').title() for slug in self.model_slugs]

        # Get mean values for imputation from the training data
        self.X_train_df = pd.read_pickle("X_train.pkl")
        self.default_values = self.X_train_df.mean()

        # List of known categorical fields that were one-hot encoded
        self.one_hot_prefixes = ['Condition_', 'Model_', 'Dealer_']  
        
        # Initialize the neural network
        self.model = ImprovedMLP(input_size=len(self.model_features))  
        self.model.load_state_dict(torch.load('best_car_model.pth', weights_only=True))
        self.model.to(device)
        self.model.eval()
        
        # Initialize LLM for information extraction
        self.ner_pipeline = pipeline(
            "token-classification",
            model="dslim/bert-base-NER",
            aggregation_strategy="simple"
        )
        
        # Initialize LLM for text understanding
        self.qa_pipeline = pipeline(
            "question-answering",
            model="distilbert-base-uncased-distilled-squad"
        )

    def extract_car_info(self, text):
        """Extract structured car information from natural language"""
        # Extract entities using NER
        entities = self.ner_pipeline(text)

        # Initialize default values
        car_info = {
            'Year': None,
            'Model': None,
            'Mileage': None,
            'Price': None,
            'Condition': None,
            'Dealer': None,
            'Monthly Payment': None,
            'Accidents': 0,  # Default to no accidents
            'Owners': 1,     # Default to 1 owner
            'Usage': 1       # Default to personal use (1)
        }


        # Simple regex-based extractions for numerical fields
        mileage_match = re.search(r'\b([0-9,]+)\s*(mi|miles)\b\.?', text, re.IGNORECASE)
        price_match = re.search(r'\$([0-9,]+)\b(?![a-zA-Z/]| per)', text)
        payment_match = re.search(r'\$([0-9,]+)\s*(?:/mo|per month)', text, re.IGNORECASE)
        year_match = re.search(r'\b(20\d{2}|19\d{2})\b', text)

        if mileage_match:
            car_info['Mileage'] = int(mileage_match.group(1).replace(',', ''))
        if price_match:
            car_info['Price'] = int(price_match.group(1).replace(',', ''))
        if payment_match:
            car_info['Monthly Payment'] = int(payment_match.group(1).replace(',', ''))
        if year_match:
            car_info['Year'] = int(year_match.group(0))

        # Extract accident information
        if re.search(r'accidents?|accident history', text, re.IGNORECASE):
            car_info['Accidents'] = 1

        # Extract owner count
        owners_match = re.search(r'(\d+)\s*(owners?|previous owners?)', text, re.IGNORECASE)
        if owners_match:
            car_info['Owners'] = int(owners_match.group(1))
        elif re.search(r'one\s*owner|single owner', text, re.IGNORECASE):
            car_info['Owners'] = 1
        elif re.search(r'two\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 2
        elif re.search(r'three\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 3
        elif re.search(r'four\+?\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 4

        # Extract usage type (mapped to your binary encoding)
        if re.search(r'commercial|business|fleet', text, re.IGNORECASE):
            car_info['Usage'] = 0  # Not personal use

        # Pull entities from NER
        for ent in entities:
            label = ent['entity_group']
            word = ent['word']

            if label == 'ORG':
                car_info['Dealer'] = word
            elif label == 'MISC' or label == 'PRODUCT':
                car_info['Model'] = word
            elif label == 'DATE' and not car_info['Year']:
                try:
                    car_info['Year'] = int(re.search(r'\d{4}', word).group(0))
                except:
                    pass

        # Try to find a matching model from the list
        found_model = None
        for model in self.model_types:
            pattern = re.compile(rf'\b{re.escape(model)}\b', re.IGNORECASE)
            if pattern.search(text):
                found_model = model
                break

        if found_model:
            car_info['Model'] = found_model

        # Extract sales condition like New, Used, Certified, etc.
        condition_match = re.search(r'\b(New|Used|Certified(?: Pre-Owned)?)\b', text, re.IGNORECASE)
        if condition_match:
            car_info['Condition'] = condition_match.group(1).title()

        if not car_info['Dealer']:
            dealer_match = re.search(
                r'\b(?:at dealer|dealer:|at)\s+([A-Z][\w&.,\- ]{2,100})',
                text,
                re.IGNORECASE
            )
            if dealer_match:
                # Clean extra whitespace and strip trailing punctuation
                dealer_name = dealer_match.group(1).strip().rstrip('.,')
                dealer_name = re.sub(r'\bdealer\b', '', dealer_name, flags=re.IGNORECASE).strip()
                car_info['Dealer'] = dealer_name

        return car_info
    
    def prepare_features(self, car_info):
        """Convert extracted car info into the model input vector"""
        # Initialize feature row with zeros
        feature_vector = np.zeros(len(self.model_features))
        feature_df = pd.DataFrame([feature_vector], columns=self.model_features)

        # Fill in numerical fields
        for col in ['Year', 'Mileage', 'Price', 'Monthly Payment', 'Accidents', 'Owners']:
            val = car_info.get(col)
            if val is not None:
                feature_df.at[0, col] = val
            else:
                feature_df.at[0, col] = self.default_values[col]

        # Fill in one-hot fields
        for prefix in self.one_hot_prefixes:
            value = car_info.get(prefix)
            if value is not None:
                encoded = f"{prefix}_{value}"
                if encoded in self.model_features:
                    feature_df.at[0, encoded] = 1.0

        # Apply input scaling
        scaled_features = self.input_scaler.transform(feature_df.values)
        
        # Convert to tensor
        return torch.tensor(scaled_features, dtype=torch.float32).to(device)

    
    def predict_score(self, text_input):
        """Main prediction pipeline"""
        # Extract information from text
        car_info = self.extract_car_info(text_input)
        print("Extracted car info:", car_info)
        
        # Prepare features for model
        features_tensor = self.prepare_features(car_info)
        
        # Make prediction
        with torch.no_grad():
            prediction = self.model(features_tensor)
            score = self.output_scaler.inverse_transform(prediction.cpu().numpy().reshape(-1, 1))
        
        return score[0][0]

# Example usage
if __name__ == "__main__":
    predictor = CarScorePredictor()

    # Define options for different fields
    years = [str(y) for y in range(1998, 2023)]

    # Extract model names from the one-hot encoded features (removing "Model_" prefix)
    sample_models = [feature.replace("Model_", "") for feature in model_features if feature.startswith("Model_")]
    mileages = [f"{x:,}" for x in range(0, 250001, 5000)]
    prices = [f"${x:,}" for x in range(4000, 120001, 2000)]
    conditions = [feature.replace("Condition_", "") for feature in model_features if feature.startswith("Condition_")]
    dealers = [feature.replace("Dealer_", "") for feature in model_features if feature.startswith("Dealer_")]
    payments = [f"${x:,}" for x in range(120, 3001, 50)]
    
    # Options for additional features
    accident_options = ["no accidents", "accident reported", "clean history", "1 accident", "accident history"]
    owner_options = ["1 owner", "2 owners", "3 owners", "4+ owners", "single owner", "one previous owner"]
    usage_options = ["private use", "commercial use", "fleet use", "personal use", "business use"]

    # Create templates with varying levels of information
    basic_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition",
        "{model} from {year} with {mileage} miles, {price}",
        "Dealer: {dealer}. {year} {model}, {mileage} miles, {price}",
        "Looking at a {year} {model}, {condition} condition, {price}"
    ]
    
    intermediate_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition, {owner}",
        "{model} ({year}), {mileage} miles, {price}, {usage}, {accident}",
        "Found a {year} {model}, {condition} condition, {price}, {owner}, {accident}",
        "{year} {model}, {mileage} miles, {price}, {usage}, dealer: {dealer}"
    ]
    
    full_info_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition, {owner}, {accident}, {usage}",
        "Dealer: {dealer}. {year} {model}, {mileage} miles, {price}, {condition}, {owner}, {usage}, {accident}",
        "Complete info: {year} {model}, {mileage} miles, {price}, {condition}, {owner}, {accident}, {usage}, dealer: {dealer}"
    ]

    # Combine all templates
    all_templates = basic_templates + intermediate_templates + full_info_templates

    # Generate 100 diverse test queries with varying information completeness
    test_queries = []
    for _ in range(100):
        template = random.choice(all_templates)
        
        # For basic templates, don't include all optional features
        if template in basic_templates:
            query = template.format(
                year=random.choice(years),
                model=random.choice(sample_models),
                mileage=random.choice(mileages),
                price=random.choice(prices),
                condition=random.choice(conditions),
                dealer=random.choice(dealers)
            )
        else:
            query = template.format(
                year=random.choice(years),
                model=random.choice(sample_models),
                mileage=random.choice(mileages),
                price=random.choice(prices),
                condition=random.choice(conditions),
                dealer=random.choice(dealers),
                accident=random.choice(accident_options),
                owner=random.choice(owner_options),
                usage=random.choice(usage_options)
            )
        test_queries.append(query)

    # Add some manual examples that cover edge cases
    test_queries.extend([
        "2021 Toyota Camry with 35,000 miles for $25,000 in used condition from AutoNation, no accidents, 1 owner",
        "2019 Honda Accord, 75,000 miles, $18,500, used condition, personal use",
        "Tesla Model 3 2022 with 12,000 miles priced at $42,000, clean history",
        "Ford F-150 2017, 120,000 miles, $22,999, used condition, commercial use, accident reported",
        "2018 Nissan Rogue, $16,500, 85,000 miles, used condition, 3 owners",
        "2018 Subaru Baja, $500 per month, 2,000 miles, used condition, 1 owner",
        "2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history"
    ])
    
    min_score = 1000 # Will store smallest tuple query
    min_query = ""

    # Test the predictor with sample queries
    for i, query in enumerate(test_queries):  # Just test first 10 for demonstration
        try:
            score = predictor.predict_score(query)

            if (score < min_score) and (query != ""):
                min_score = score
                min_query = query
            
            print(f"Query {i+1}: {query}")
            print(f"Predicted Score: {score:.2f}\n")
        except Exception as e:
            print(f"Error processing query: {query}")
            print(f"Error: {str(e)}\n")
    
    print(f"Min Query: {min_query}")
    print(f"Min Score: {min_score:.2f}\n")
# Out:
# Extracted car info: {'Year': 2018, 'Model': 'Chevrolet Equinox', 'Mileage': None, 'Price': 26000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 1: Found a 2018 Chevrolet Equinox RS, Used condition, $26,000, one previous owner, no accidents
# Predicted Score: 48.89
#
# Extracted car info: {'Year': 2001, 'Model': 'Cadillac Xts', 'Mileage': None, 'Price': 34000, 'Condition': 'New', 'Dealer': 'a 2001 Cadillac XTS Luxury, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 2: Looking at a 2001 Cadillac XTS Luxury, New condition, $34,000
# Predicted Score: 41.41
#
# Extracted car info: {'Year': 2018, 'Model': 'Chevrolet Tahoe', 'Mileage': None, 'Price': 36000, 'Condition': 'New', 'Dealer': 'a 2018 Chevrolet Tahoe LT, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 3: Looking at a 2018 Chevrolet Tahoe LT, New condition, $36,000
# Predicted Score: 41.84
#
# Extracted car info: {'Year': 2001, 'Model': 'Ford Bronco', 'Mileage': 30000, 'Price': 92000, 'Condition': 'Used', 'Dealer': 'Ford Bronco', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 2, 'Usage': 0}
# Query 4: Complete info: 2001 Ford Bronco Sport Heritage, 30,000 miles, $92,000, Used, 2 owners, clean history, fleet use, dealer: Gerald Nissan of Naperville
# Predicted Score: 57.35
#
# Extracted car info: {'Year': 2012, 'Model': 'Jeep Grand Cherokee', 'Mileage': None, 'Price': 68000, 'Condition': 'New', 'Dealer': '##K', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 1}
# Query 5: Found a 2012 Jeep Grand Cherokee WK Limited, New condition, $68,000, 3 owners, 1 accident
# Predicted Score: 66.58
#
# Extracted car info: {'Year': 2022, 'Model': 'Ford Torino', 'Mileage': 80000, 'Price': 86000, 'Condition': None, 'Dealer': 'Volkswagen of Highland', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 6: Complete info: 2022 Ford Torino, 80,000 miles, $86,000, Other, single owner, no accidents, private use, dealer: City Volkswagen of Highland
# Predicted Score: 63.45
#
# Extracted car info: {'Year': 1998, 'Model': 'Mercedes - Benz AMG GT 55 C', 'Mileage': 220000, 'Price': 28000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 7: Mercedes-Benz AMG GT 55 C (1998), 220,000 miles, $28,000, commercial use, clean history
# Predicted Score: 47.21
#
# Extracted car info: {'Year': 2004, 'Model': 'Bmw 325', 'Mileage': 200000, 'Price': 56000, 'Condition': None, 'Dealer': 'CarMax Live Oak', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 8: Dealer: CarMax Live Oak. 2004 BMW 325 325xi AWD 4dr Wagon, 200,000 miles, $56,000
# Predicted Score: 51.12
#
# Extracted car info: {'Year': 2018, 'Model': 'Acura Integra', 'Mileage': None, 'Price': 78000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 9: Found a 2018 Acura Integra A-Spec, Other condition, $78,000, 4+ owners, 1 accident
# Predicted Score: 60.34
#
# Extracted car info: {'Year': 2016, 'Model': 'Nissan Nv Cargo', 'Mileage': 235000, 'Price': 114000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 10: Nissan NV Cargo NV2500 HD SV V6/SV V8 (2016), 235,000 miles, $114,000, business use, 1 accident
# Predicted Score: 70.66
#
# Extracted car info: {'Year': 2007, 'Model': 'Mercedes - Benz AMG GT S', 'Mileage': None, 'Price': 96000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 11: Found a 2007 Mercedes-Benz AMG GT S, New condition, $96,000, single owner, clean history
# Predicted Score: 53.89
#
# Extracted car info: {'Year': 1998, 'Model': 'Volvo Xc90', 'Mileage': 160000, 'Price': 18000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 12: Volvo XC90 Recharge Plug-In Hybrid T8 Inscription 6 Passenger (1998), 160,000 miles, $18,000, business use, clean history
# Predicted Score: 43.17
#
# Extracted car info: {'Year': 2009, 'Model': 'Bentley Continental', 'Mileage': 165000, 'Price': 32000, 'Condition': None, 'Dealer': 'Atiyath. 2009 Bentley Continental GT V8, 165,000 miles', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 13: Dealer: Atiyath. 2009 Bentley Continental GT V8, 165,000 miles, $32,000
# Predicted Score: 44.37
#
# Extracted car info: {'Year': 2008, 'Model': 'Nissan Sentra', 'Mileage': 60000, 'Price': 50000, 'Condition': None, 'Dealer': 'Access Automotive', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 14: 2008 Nissan Sentra SR, 60,000 miles, $50,000, fleet use, dealer: Access Automotive
# Predicted Score: 45.62
#
# Extracted car info: {'Year': 2000, 'Model': '9', 'Mileage': 200000, 'Price': 90000, 'Condition': None, 'Dealer': '##ra', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 15: Dealer: Acura Highland Park. 2000 Mazda CX-9 Carbon Edition, 200,000 miles, $90,000
# Predicted Score: 58.85
#
# Extracted car info: {'Year': 2011, 'Model': 'Cadillac Escalade', 'Mileage': 215000, 'Price': 56000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 16: 2011 Cadillac Escalade Luxury, 215,000 miles, $56,000, New condition, 4+ owners, 1 accident, fleet use
# Predicted Score: 60.79
#
# Extracted car info: {'Year': 2021, 'Model': 'Cadillac Ct6', 'Mileage': 100000, 'Price': 12000, 'Condition': None, 'Dealer': 'Porsche Exchange', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 17: Complete info: 2021 Cadillac CT6 3.0L Twin Turbo Luxury, 100,000 miles, $12,000, Other, 4+ owners, accident reported, personal use, dealer: The Porsche Exchange
# Predicted Score: 47.65
#
# Extracted car info: {'Year': 2005, 'Model': 'Bmw 325', 'Mileage': 190000, 'Price': 106000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 18: 2005 BMW 325 i, 190,000 miles, $106,000, Other condition
# Predicted Score: 61.22
#
# Extracted car info: {'Year': 2007, 'Model': 'Pontiac Firebird Trans Am SLP Firehawk', 'Mileage': 220000, 'Price': 28000, 'Condition': None, 'Dealer': 'Xchange Motors', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 19: Dealer: Xchange Motors. 2007 Pontiac Firebird Trans Am SLP Firehawk, 220,000 miles, $28,000
# Predicted Score: 45.70
#
# Extracted car info: {'Year': 2013, 'Model': 'Land Rover Defender', 'Mileage': 135000, 'Price': 80000, 'Condition': 'New', 'Dealer': 'Rover', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 0}
# Query 20: 2013 Land Rover Defender 110 P500 SE, 135,000 miles, $80,000, New condition, 3 owners, accident reported, commercial use
# Predicted Score: 70.37
#
# Extracted car info: {'Year': 2016, 'Model': 'Volvo Xc60', 'Mileage': 35000, 'Price': 88000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 21: Volvo XC60 T6 Inscription (2016), 35,000 miles, $88,000, business use, 1 accident
# Predicted Score: 62.84
#
# Extracted car info: {'Year': 2005, 'Model': 'Aston Martin Dbs', 'Mileage': 15000, 'Price': 18000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 22: Aston Martin DBS Volante (2005), 15,000 miles, $18,000, commercial use, clean history
# Predicted Score: 38.85
#
# Extracted car info: {'Year': 2022, 'Model': 'Volkswagen Atlas', 'Mileage': 175000, 'Price': 72000, 'Condition': 'Used', 'Dealer': 'Audi Hoffman Estates', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 23: Complete info: 2022 Volkswagen Atlas Cross Sport 2.0T SE, 175,000 miles, $72,000, Used, one previous owner, accident reported, business use, dealer: Audi Hoffman Estates
# Predicted Score: 62.74
#
# Extracted car info: {'Year': 2016, 'Model': 'Acura Mdx', 'Mileage': 165000, 'Price': 104000, 'Condition': None, 'Dealer': 'Titan Auto Sales', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 24: 2016 Acura MDX 3.5L w/Technology Package, 165,000 miles, $104,000, business use, dealer: Titan Auto Sales
# Predicted Score: 59.05
#
# Extracted car info: {'Year': 2020, 'Model': 'Ford Fusion', 'Mileage': 75000, 'Price': 30000, 'Condition': None, 'Dealer': '##gi Titan', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 25: Ford Fusion Energi Titanium from 2020 with 75,000 miles, $30,000
# Predicted Score: 41.78
#
# Extracted car info: {'Year': 2014, 'Model': 'Aston Martin V12 Vanquish', 'Mileage': 100000, 'Price': 58000, 'Condition': 'Used', 'Dealer': 'Ali Luxury Motors', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 0}
# Query 26: Complete info: 2014 Aston Martin V12 Vanquish Base, 100,000 miles, $58,000, Used, 3 owners, accident reported, business use, dealer: Ali Luxury Motors
# Predicted Score: 66.25
#
# Extracted car info: {'Year': 2019, 'Model': 'Lexus Gs 350', 'Mileage': None, 'Price': 64000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 27: Found a 2019 Lexus GS 350 Crafted Line, New condition, $64,000, single owner, clean history
# Predicted Score: 47.84
#
# Extracted car info: {'Year': 2006, 'Model': 'Bmw X4', 'Mileage': 150000, 'Price': 62000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 28: 2006 BMW X4 M40I, 150,000 miles, $62,000, Other condition, single owner, accident history, commercial use
# Predicted Score: 60.35
#
# Extracted car info: {'Year': 2010, 'Model': 'Chevrolet Silverado 1500', 'Mileage': 185000, 'Price': 60000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 29: Chevrolet Silverado 1500 RST (2010), 185,000 miles, $60,000, personal use, 1 accident
# Predicted Score: 60.81
#
# Extracted car info: {'Year': 2006, 'Model': 'Toyota Highlander', 'Mileage': 125000, 'Price': 34000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 30: Toyota Highlander LE (2006), 125,000 miles, $34,000, personal use, clean history
# Predicted Score: 43.95
#
# Extracted car info: {'Year': 2013, 'Model': 'Hyundai Sonata', 'Mileage': 175000, 'Price': 44000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 31: Hyundai Sonata Sport from 2013 with 175,000 miles, $44,000
# Predicted Score: 46.69
#
# Extracted car info: {'Year': 2007, 'Model': 'Volvo Xc40', 'Mileage': None, 'Price': 120000, 'Condition': 'Used', 'Dealer': 'a 2007 Volvo XC40 B5 Plus Bright Theme, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 32: Looking at a 2007 Volvo XC40 B5 Plus Bright Theme, Used condition, $120,000
# Predicted Score: 58.84
#
# Extracted car info: {'Year': 2012, 'Model': 'Acura Tlx', 'Mileage': 140000, 'Price': 106000, 'Condition': 'New', 'Dealer': '##LX', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 33: 2012 Acura TLX Base, 140,000 miles, $106,000, New condition, 1 owner, accident reported, personal use
# Predicted Score: 67.89
#
# Extracted car info: {'Year': 2004, 'Model': 'Nissan Xterra', 'Mileage': None, 'Price': 90000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 1}
# Query 34: Found a 2004 Nissan Xterra X, Used condition, $90,000, 3 owners, 1 accident
# Predicted Score: 69.99
#
# Extracted car info: {'Year': 2015, 'Model': 'Volkswagen Jetta', 'Mileage': None, 'Price': 64000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 35: Found a 2015 Volkswagen Jetta 1.5T Sport, Other condition, $64,000, single owner, accident reported
# Predicted Score: 56.87
#
# Extracted car info: {'Year': 2005, 'Model': 'Infiniti Qx80', 'Mileage': 60000, 'Price': 92000, 'Condition': 'Used', 'Dealer': '##NI', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 36: 2005 INFINITI QX80 SENSORY AWD, 60,000 miles, $92,000, Used condition, single owner
# Predicted Score: 54.36
#
# Extracted car info: {'Year': 2008, 'Model': 'Dodge Charger', 'Mileage': None, 'Price': 90000, 'Condition': 'New', 'Dealer': 'a 2008 Dodge Charger SXT, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 37: Looking at a 2008 Dodge Charger SXT, New condition, $90,000
# Predicted Score: 52.63
#
# Extracted car info: {'Year': 2013, 'Model': 'Volkswagen Jetta', 'Mileage': 145000, 'Price': 94000, 'Condition': 'Used', 'Dealer': '##son Hyundai', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 38: Complete info: 2013 Volkswagen Jetta 1.5T Sport, 145,000 miles, $94,000, Used, 1 owner, 1 accident, commercial use, dealer: Ettleson Hyundai
# Predicted Score: 66.04
#
# Extracted car info: {'Year': 2010, 'Model': 'Hyundai Tucson', 'Mileage': 25000, 'Price': 86000, 'Condition': None, 'Dealer': 'Hyundai Tucson Limited', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 39: Hyundai Tucson Limited from 2010 with 25,000 miles, $86,000
# Predicted Score: 52.19
#
# Extracted car info: {'Year': 1999, 'Model': 'Toyota Highlander', 'Mileage': 145000, 'Price': 80000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 40: Toyota Highlander Hybrid Limited Platinum from 1999 with 145,000 miles, $80,000
# Predicted Score: 55.20
#
# Extracted car info: {'Year': 2007, 'Model': 'Land Rover Range Rover', 'Mileage': 65000, 'Price': 16000, 'Condition': 'New', 'Dealer': 'Land Rover Range Rover', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 41: 2007 Land Rover Range Rover P400 SE, 65,000 miles, $16,000, New condition, one previous owner, 1 accident, personal use
# Predicted Score: 47.53
#
# Extracted car info: {'Year': 2000, 'Model': 'Hyundai Tucson', 'Mileage': 120000, 'Price': 116000, 'Condition': None, 'Dealer': 'CarMax Norco', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 0}
# Query 42: Complete info: 2000 Hyundai Tucson XRT, 120,000 miles, $116,000, Other, 2 owners, accident history, commercial use, dealer: CarMax Norco
# Predicted Score: 71.50
#
# Extracted car info: {'Year': 2008, 'Model': '50', 'Mileage': None, 'Price': 88000, 'Condition': 'New', 'Dealer': 'a 2008 Mazda CX-50 2.5 Turbo, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 43: Looking at a 2008 Mazda CX-50 2.5 Turbo, New condition, $88,000
# Predicted Score: 52.19
#
# Extracted car info: {'Year': 2003, 'Model': 'Bmw 435', 'Mileage': None, 'Price': 72000, 'Condition': 'New', 'Dealer': 'a 2003 BMW 435 i xDrive, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 44: Looking at a 2003 BMW 435 i xDrive, New condition, $72,000
# Predicted Score: 48.90
#
# Extracted car info: {'Year': 2016, 'Model': 'Kia Seltos', 'Mileage': 245000, 'Price': 20000, 'Condition': 'New', 'Dealer': 'Seltos', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 45: 2016 Kia Seltos SX, 245,000 miles, $20,000, New condition, 2 owners, 1 accident, personal use
# Predicted Score: 58.45
#
# Extracted car info: {'Year': 2009, 'Model': 'Aston Martin Dbs', 'Mileage': 0, 'Price': 82000, 'Condition': None, 'Dealer': 'Ph', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 46: 2009 Aston Martin DBS ULTIMATE 770, 0 miles, $82,000, private use, dealer: CarMax Pharr
# Predicted Score: 50.96
#
# Extracted car info: {'Year': 2005, 'Model': 'Porsche Macan', 'Mileage': 145000, 'Price': 88000, 'Condition': None, 'Dealer': 'Mac', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 47: Porsche Macan Electric 4 (2005), 145,000 miles, $88,000, personal use, 1 accident
# Predicted Score: 65.14
#
# Extracted car info: {'Year': 2008, 'Model': 'Kia Sorento', 'Mileage': 195000, 'Price': 58000, 'Condition': 'New', 'Dealer': 'CarMax Midlothian', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 48: Complete info: 2008 Kia Sorento EX, 195,000 miles, $58,000, New, 1 owner, no accidents, personal use, dealer: CarMax Midlothian
# Predicted Score: 60.76
#
# Extracted car info: {'Year': 2012, 'Model': 'Volvo Xc90', 'Mileage': 160000, 'Price': 30000, 'Condition': None, 'Dealer': 'CarMax F', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 49: 2012 Volvo XC90 T6 Inscription, 160,000 miles, $30,000, private use, dealer: CarMax Ft. Lauderdale
# Predicted Score: 43.56
#
# Extracted car info: {'Year': 2009, 'Model': 'Bentley Arnage', 'Mileage': None, 'Price': 20000, 'Condition': None, 'Dealer': 'a 2009 Bentley Arnage T, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 50: Looking at a 2009 Bentley Arnage T, Other condition, $20,000
# Predicted Score: 38.74
#
# Extracted car info: {'Year': 1999, 'Model': 'Rolls - Royce Phantom VI Base', 'Mileage': None, 'Price': 120000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 51: Found a 1999 Rolls-Royce Phantom VI Base, New condition, $120,000, single owner, accident history
# Predicted Score: 67.57
#
# Extracted car info: {'Year': 2018, 'Model': 'Acura Integra', 'Mileage': None, 'Price': 78000, 'Condition': 'New', 'Dealer': '##pec Technology', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 52: Found a 2018 Acura Integra A-Spec Technology, New condition, $78,000, 2 owners, accident history
# Predicted Score: 64.72
#
# Extracted car info: {'Year': 1998, 'Model': 'Aston Martin Vanquish', 'Mileage': None, 'Price': 30000, 'Condition': 'Used', 'Dealer': 'a 1998 Aston Martin Vanquish Volante, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 53: Looking at a 1998 Aston Martin Vanquish Volante, Used condition, $30,000
# Predicted Score: 40.86
#
# Extracted car info: {'Year': 2001, 'Model': 'Dodge Caravan', 'Mileage': 100000, 'Price': 56000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 54: 2001 Dodge Caravan SE 4dr Mini Van, 100,000 miles, $56,000, Other condition, one previous owner, clean history, private use
# Predicted Score: 48.38
#
# Extracted car info: {'Year': 2017, 'Model': 'Chevrolet Equinox', 'Mileage': 25000, 'Price': 20000, 'Condition': None, 'Dealer': 'Chevrolet Equinox', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 55: Chevrolet Equinox FWD ACTIV from 2017 with 25,000 miles, $20,000
# Predicted Score: 39.08
#
# Extracted car info: {'Year': 2007, 'Model': 'Benz AMG G', 'Mileage': 115000, 'Price': 44000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 56: 2007 Mercedes-Benz AMG GLC 43 Base 4MATIC, 115,000 miles, $44,000, New condition, one previous owner, 1 accident, business use
# Predicted Score: 55.11
#
# Extracted car info: {'Year': 2020, 'Model': 'Volvo Xc90', 'Mileage': 90000, 'Price': 6000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 57: 2020 Volvo XC90 B6 Plus 7-Seater, 90,000 miles, $6,000, New condition, one previous owner, 1 accident, fleet use
# Predicted Score: 46.31
#
# Extracted car info: {'Year': 2009, 'Model': 'Ford Shelby Gt350', 'Mileage': 45000, 'Price': 34000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 58: 2009 Ford Shelby GT350 Base, 45,000 miles, $34,000, Used condition
# Predicted Score: 41.97
#
# Extracted car info: {'Year': 2006, 'Model': 'Buick Enclave', 'Mileage': 50000, 'Price': 62000, 'Condition': 'Used', 'Dealer': 'Avenir AWD', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 59: 2006 Buick Enclave Avenir AWD, 50,000 miles, $62,000, Used condition
# Predicted Score: 47.97
#
# Extracted car info: {'Year': 2020, 'Model': 'Chevrolet Avalanche', 'Mileage': 140000, 'Price': 10000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 60: Chevrolet Avalanche 1500 LTZ (2020), 140,000 miles, $10,000, personal use, accident history
# Predicted Score: 48.13
#
# Extracted car info: {'Year': 2020, 'Model': 'Audi Rs Q8', 'Mileage': 150000, 'Price': 30000, 'Condition': 'Used', 'Dealer': '##ra', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 61: Dealer: Acura Highland Park. 2020 Audi RS Q8 4.0T, 150,000 miles, $30,000, Used, 1 owner, fleet use, no accidents
# Predicted Score: 52.75
#
# Extracted car info: {'Year': 2017, 'Model': 'Audi S5', 'Mileage': None, 'Price': 44000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 2, 'Usage': 1}
# Query 62: Found a 2017 Audi S5 Prestige, New condition, $44,000, 2 owners, clean history
# Predicted Score: 46.71
#
# Extracted car info: {'Year': 2015, 'Model': 'Audi A8', 'Mileage': None, 'Price': 26000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 3, 'Usage': 1}
# Query 63: Found a 2015 Audi A8 e L 60, New condition, $26,000, 3 owners, accident reported
# Predicted Score: 57.68
#
# Extracted car info: {'Year': 2016, 'Model': 'Bmw X3', 'Mileage': 15000, 'Price': 96000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 64: 2016 BMW X3 xDrive30i, 15,000 miles, $96,000, Other condition
# Predicted Score: 54.35
#
# Extracted car info: {'Year': 2003, 'Model': 'Kia Niro', 'Mileage': 145000, 'Price': 8000, 'Condition': None, 'Dealer': 'Ni', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 65: Kia Niro EV EX (2003), 145,000 miles, $8,000, private use, accident history
# Predicted Score: 49.20
#
# Extracted car info: {'Year': 2001, 'Model': 'Prestige', 'Mileage': 80000, 'Price': 52000, 'Condition': 'Used', 'Dealer': 'Audi', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 66: 2001 Audi e-tron S Prestige, 80,000 miles, $52,000, Used condition, single owner, clean history, private use
# Predicted Score: 46.98
#
# Extracted car info: {'Year': 2009, 'Model': 'Mercedes', 'Mileage': 185000, 'Price': 36000, 'Condition': None, 'Dealer': 'Benz AMG GLC', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 67: Mercedes-Benz AMG GLC 63 4MATIC+ Coupe (2009), 185,000 miles, $36,000, private use, accident history
# Predicted Score: 55.60
#
# Extracted car info: {'Year': 2000, 'Model': 'Jeep Grand Wagoneer', 'Mileage': 195000, 'Price': 28000, 'Condition': 'New', 'Dealer': 'Ali Luxury Motors', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 68: Dealer: Ali Luxury Motors. 2000 Jeep Grand Wagoneer Series III 4x4, 195,000 miles, $28,000, New, one previous owner, personal use, 1 accident
# Predicted Score: 55.19
#
# Extracted car info: {'Year': 2022, 'Model': 'Ford F - 250 XLT', 'Mileage': 210000, 'Price': 4000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 69: 2022 Ford F-250 XLT, 210,000 miles, $4,000, Used condition
# Predicted Score: 40.03
#
# Extracted car info: {'Year': 1998, 'Model': 'Pontiac G6 GT', 'Mileage': 55000, 'Price': 24000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 70: 1998 Pontiac G6 GT, 55,000 miles, $24,000, New condition, one previous owner, clean history, business use
# Predicted Score: 41.02
#
# Extracted car info: {'Year': 2021, 'Model': 'Miata', 'Mileage': 95000, 'Price': 108000, 'Condition': None, 'Dealer': '##son Hyundai', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 71: Complete info: 2021 Mazda MX-5 Miata 2dr Convertible Manual, 95,000 miles, $108,000, Other, 1 owner, clean history, private use, dealer: Ettleson Hyundai
# Predicted Score: 58.21
#
# Extracted car info: {'Year': 2012, 'Model': 'Volkswagen Tiguan', 'Mileage': None, 'Price': 46000, 'Condition': None, 'Dealer': 'a 2012 Volkswagen Tiguan 2.0T Wolfsburg Edition, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 72: Looking at a 2012 Volkswagen Tiguan 2.0T Wolfsburg Edition, Other condition, $46,000
# Predicted Score: 43.71
#
# Extracted car info: {'Year': 2010, 'Model': 'Honda Accord', 'Mileage': 175000, 'Price': 46000, 'Condition': None, 'Dealer': 'Access Automotive', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 73: Dealer: Access Automotive. 2010 Honda Accord Hybrid Base, 175,000 miles, $46,000
# Predicted Score: 47.40
#
# Extracted car info: {'Year': 2020, 'Model': 'Bmw X4', 'Mileage': 170000, 'Price': 102000, 'Condition': None, 'Dealer': 'Toyota', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 74: 2020 BMW X4 xDrive30i, 170,000 miles, $102,000, private use, dealer: Toyota of Lincoln Park
# Predicted Score: 58.67
#
# Extracted car info: {'Year': 2001, 'Model': 'Dodge Caravan', 'Mileage': 215000, 'Price': 82000, 'Condition': 'New', 'Dealer': 'CarMax Columbus', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 75: Complete info: 2001 Dodge Caravan SE 4dr Mini Van, 215,000 miles, $82,000, New, one previous owner, no accidents, personal use, dealer: CarMax Columbus
# Predicted Score: 65.74
#
# Extracted car info: {'Year': 2017, 'Model': 'Audi Rs 3', 'Mileage': 105000, 'Price': 76000, 'Condition': 'New', 'Dealer': 'Castle Buick GMC', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 76: Dealer: Castle Buick GMC. 2017 Audi RS 3 2.5T, 105,000 miles, $76,000, New, 1 owner, private use, clean history
# Predicted Score: 51.68
#
# Extracted car info: {'Year': 2005, 'Model': None, 'Mileage': 110000, 'Price': 8000, 'Condition': None, 'Dealer': 'Hu', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 77: Hummer H3 Base (2005), 110,000 miles, $8,000, private use, accident reported
# Predicted Score: 47.77
#
# Extracted car info: {'Year': 2001, 'Model': 'Lamborghini Huracan', 'Mileage': None, 'Price': 46000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 78: Found a 2001 Lamborghini Huracan EVO Spyder RWD, Used condition, $46,000, 1 owner, no accidents
# Predicted Score: 52.53
#
# Extracted car info: {'Year': 2019, 'Model': 'Audi A3', 'Mileage': 80000, 'Price': 118000, 'Condition': 'New', 'Dealer': 'Eisenhower Expy', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 79: Complete info: 2019 Audi A3 2.0T Tech Premium, 80,000 miles, $118,000, New, 4+ owners, accident history, private use, dealer: CarMax Hillside (Eisenhower Expy)
# Predicted Score: 69.16
#
# Extracted car info: {'Year': 2006, 'Model': 'Lamborghini Huracan', 'Mileage': 60000, 'Price': 86000, 'Condition': None, 'Dealer': 'Lamborghini Hurac', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 80: Dealer: Ace Motorworks. 2006 Lamborghini Huracan Performante LP640-4 Underground Racing Stage III+ Plus Billet Built Trans!, 60,000 miles, $86,000
# Predicted Score: 53.07
#
# Extracted car info: {'Year': 2006, 'Model': 'Chevrolet Colorado', 'Mileage': 80000, 'Price': 76000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 81: 2006 Chevrolet Colorado WT, 80,000 miles, $76,000, Other condition, single owner, accident history, commercial use
# Predicted Score: 61.05
#
# Extracted car info: {'Year': 2012, 'Model': 'Lexus Is 350', 'Mileage': 225000, 'Price': 90000, 'Condition': None, 'Dealer': 'CarMax College Station', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 82: 2012 Lexus IS 350 F SPORT Design, 225,000 miles, $90,000, private use, dealer: CarMax College Station
# Predicted Score: 58.15
#
# Extracted car info: {'Year': 2021, 'Model': 'Jeep Renegade', 'Mileage': 50000, 'Price': 88000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 83: Jeep Renegade Latitude from 2021 with 50,000 miles, $88,000
# Predicted Score: 53.47
#
# Extracted car info: {'Year': 1998, 'Model': 'Hyundai Tucson', 'Mileage': 150000, 'Price': 120000, 'Condition': None, 'Dealer': 'Tucson', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 84: 1998 Hyundai Tucson XRT, 150,000 miles, $120,000, Other condition, 4+ owners
# Predicted Score: 63.30
#
# Extracted car info: {'Year': 2006, 'Model': 'Volkswagen Jetta', 'Mileage': None, 'Price': 108000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 85: Found a 2006 Volkswagen Jetta GLI 2.0T Autobahn, New condition, $108,000, 4+ owners, clean history
# Predicted Score: 56.32
#
# Extracted car info: {'Year': 2014, 'Model': 'Ram Promaster 1500', 'Mileage': 60000, 'Price': 24000, 'Condition': None, 'Dealer': 'Autobarn Mazda', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 86: 2014 RAM ProMaster 1500 Base, 60,000 miles, $24,000, commercial use, dealer: The Autobarn Mazda of Evanston
# Predicted Score: 40.27
#
# Extracted car info: {'Year': 1998, 'Model': 'Cadillac Seville', 'Mileage': 20000, 'Price': 8000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 87: Cadillac Seville SLS (1998), 20,000 miles, $8,000, commercial use, no accidents
# Predicted Score: 45.94
#
# Extracted car info: {'Year': 2009, 'Model': 'Nissan Versa', 'Mileage': 235000, 'Price': 36000, 'Condition': None, 'Dealer': 'Woodfield Nissan', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 88: Complete info: 2009 Nissan Versa 1.6 SV, 235,000 miles, $36,000, Other, one previous owner, clean history, personal use, dealer: Woodfield Nissan
# Predicted Score: 47.46
#
# Extracted car info: {'Year': 2004, 'Model': 'Genesis Gv70', 'Mileage': None, 'Price': 28000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 89: Found a 2004 Genesis GV70 Sport, Other condition, $28,000, one previous owner, 1 accident
# Predicted Score: 48.59
#
# Extracted car info: {'Year': 2004, 'Model': 'Mini Countryman', 'Mileage': None, 'Price': 40000, 'Condition': 'Used', 'Dealer': 'a 2004 MINI Countryman Cooper S ALL4, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 90: Looking at a 2004 MINI Countryman Cooper S ALL4, Used condition, $40,000
# Predicted Score: 42.55
#
# Extracted car info: {'Year': 2000, 'Model': 'Fiat 500', 'Mileage': 180000, 'Price': 102000, 'Condition': None, 'Dealer': 'CarMax Vancouver', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 91: Dealer: CarMax Vancouver. 2000 FIAT 500 Abarth, 180,000 miles, $102,000, Other, single owner, commercial use, accident history
# Predicted Score: 68.18
#
# Extracted car info: {'Year': 2001, 'Model': 'Chevrolet Chevelle SS', 'Mileage': 20000, 'Price': 46000, 'Condition': None, 'Dealer': 'Genesis of Downers Grove', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 92: 2001 Chevrolet Chevelle SS, 20,000 miles, $46,000, business use, dealer: Genesis of Downers Grove
# Predicted Score: 44.33
#
# Extracted car info: {'Year': 2000, 'Model': 'Chevrolet Express 2500', 'Mileage': 120000, 'Price': 12000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 93: 2000 Chevrolet Express 2500, 120,000 miles, $12,000, New condition
# Predicted Score: 40.76
#
# Extracted car info: {'Year': 2001, 'Model': None, 'Mileage': 135000, 'Price': 34000, 'Condition': None, 'Dealer': 'Auto', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 94: 2001 Hummer H2, 135,000 miles, $34,000, personal use, dealer: West Chicago Auto Mall
# Predicted Score: 44.74
#
# Extracted car info: {'Year': 2014, 'Model': 'Kia K5', 'Mileage': 165000, 'Price': 102000, 'Condition': 'Used', 'Dealer': 'Sub', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 95: Complete info: 2014 Kia K5 GT-Line, 165,000 miles, $102,000, Used, 4+ owners, 1 accident, fleet use, dealer: The Autobarn Countryside Subaru
# Predicted Score: 67.68
#
# Extracted car info: {'Year': 2015, 'Model': 'Chevrolet Equinox', 'Mileage': 15000, 'Price': 62000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 96: 2015 Chevrolet Equinox FWD RS, 15,000 miles, $62,000, Used condition, one previous owner
# Predicted Score: 47.42
#
# Extracted car info: {'Year': 2006, 'Model': 'Porsche Panamera', 'Mileage': 205000, 'Price': 102000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 97: Porsche Panamera E-Hybrid 4S (2006), 205,000 miles, $102,000, fleet use, no accidents
# Predicted Score: 68.54
#
# Extracted car info: {'Year': 2007, 'Model': 'Hyundai Veracruz', 'Mileage': 80000, 'Price': 54000, 'Condition': None, 'Dealer': 'Jaguar Schaumburg', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 2, 'Usage': 0}
# Query 98: Complete info: 2007 Hyundai Veracruz Limited, 80,000 miles, $54,000, Other, 2 owners, clean history, business use, dealer: Jaguar Schaumburg
# Predicted Score: 50.33
#
# Extracted car info: {'Year': 2010, 'Model': '##stige', 'Mileage': 250000, 'Price': 118000, 'Condition': 'Used', 'Dealer': 't', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 99: 2010 Audi e-tron Sportback S line Prestige, 250,000 miles, $118,000, Used condition
# Predicted Score: 64.41
#
# Extracted car info: {'Year': 2020, 'Model': 'Kia Sorento', 'Mileage': 235000, 'Price': 90000, 'Condition': None, 'Dealer': 'So', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 100: 2020 Kia Sorento EX, 235,000 miles, $90,000, commercial use, dealer: Ray Buick
# Predicted Score: 57.67
#
# Extracted car info: {'Year': 2021, 'Model': 'Toyota Camry', 'Mileage': 35000, 'Price': 25000, 'Condition': 'Used', 'Dealer': 'AutoNation', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 101: 2021 Toyota Camry with 35,000 miles for $25,000 in used condition from AutoNation, no accidents, 1 owner
# Predicted Score: 49.35
#
# Extracted car info: {'Year': 2019, 'Model': 'Honda Accord', 'Mileage': 75000, 'Price': 18500, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 102: 2019 Honda Accord, 75,000 miles, $18,500, used condition, personal use
# Predicted Score: 39.63
#
# Extracted car info: {'Year': 2022, 'Model': 'Tesla Model 3', 'Mileage': 12000, 'Price': 42000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 103: Tesla Model 3 2022 with 12,000 miles priced at $42,000, clean history
# Predicted Score: 43.46
#
# Extracted car info: {'Year': 2017, 'Model': 'Ford F - 150', 'Mileage': 120000, 'Price': 22999, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 104: Ford F-150 2017, 120,000 miles, $22,999, used condition, commercial use, accident reported
# Predicted Score: 50.20
#
# Extracted car info: {'Year': 2018, 'Model': 'Nissan Rogue', 'Mileage': 85000, 'Price': 16500, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 1}
# Query 105: 2018 Nissan Rogue, $16,500, 85,000 miles, used condition, 3 owners
# Predicted Score: 46.05
#
# Extracted car info: {'Year': 2018, 'Model': 'Subaru Baja', 'Mileage': 2000, 'Price': None, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': 500, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 106: 2018 Subaru Baja, $500 per month, 2,000 miles, used condition, 1 owner
# Predicted Score: 39.97
#
# Extracted car info: {'Year': 2022, 'Model': 'Toyota Camry', 'Mileage': 12000, 'Price': 9000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 107: 2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history
# Predicted Score: 37.32
#
# Min Query: 2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history
# Min Score: 37.32
