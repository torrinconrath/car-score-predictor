# %% [markdown]
# Current Model Notebook

# %%
# Create the dataset

import numpy as np
import pandas as pd
from datetime import datetime
import random as rand
from sklearn.feature_selection import SelectPercentile, f_regression
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
import torch
import json
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import joblib
import warnings
from transformers import logging
import joblib
from math import log

# Ignore specific warnings and logs
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning, module='tqdm')
logging.set_verbosity_error() 

# Read the file
df = pd.read_csv("training_cars_data.csv")

# Make Car Model into two different columns
if 'Car Model' in df.columns:
    df[['Year', 'Model']] = df['Car Model'].str.extract(r'(\d{4})\s(.*)')
    df = df.drop(columns=['Car Model'])

if 'Price (USD)' in df.columns:
    df = df.rename(columns={'Price (USD)': 'Price'})

if 'Dealer Name' in df.columns:
    df = df.rename(columns={'Dealer Name': 'Dealer'})

# Standardize all matching rows to 'Certified'
df['Condition'] = df['Condition'].apply(
    lambda x: 'Certified' if 'certified' in str(x).lower() else x
)
# Clean condition column
df['Condition'] = df['Condition'].replace([
    'Prequalify now', 'stock_type', 'New & Used', np.nan
], 'Other')

# List of columns to clean
columns_to_clean = ['Monthly Payment', 'Mileage', 'Price', 'Year']

# Apply cleaning function to all specified columns
df[columns_to_clean] = df[columns_to_clean].apply(lambda x: x.str.replace(r'\D', '', regex=True))

# Convert to numeric while preserving NaNs
df[columns_to_clean] = df[columns_to_clean].apply(pd.to_numeric, errors='coerce')

# Set empty Mileage values to 0
df['Mileage'] = df['Mileage'].fillna(0)

# Synthetic feature generation
def random_accident(row):
    return rand.choices([1, 0], weights=[30, 70], k=1)[0]  # 1 = accident, 0 = no accident

def random_owners(row):
    numbers = [0, 1, 2, 3, 4]
    weights = [40, 40, 30, 20, 10]
    return rand.choices(numbers, weights=weights, k=1)[0] 

def random_usage(row):
    return rand.choices([1, 0], weights=[80, 20], k=1)[0]  # 1 = personal use, 0 = not personal

# Apply the random features
df['Accidents'] = df.apply(random_accident, axis=1)
df['Owners'] = df.apply(random_owners, axis=1)
df['Usage'] = df.apply(random_usage, axis=1) 

# Feature engineering
current_year = datetime.now().year
df['Age'] = current_year - df['Year']
df['MilesPerYear'] = df['Mileage'] / (df['Age'] + 1)
df['PricePerMile'] = df['Price'] / (df['Mileage'] + 1)

# Hot-one encoding
df = pd.get_dummies(df, columns=['Condition', 'Model', 'Dealer'], drop_first=False)

# def simple_scoring(row):
#     if pd.isna(row['Mileage']) or pd.isna(row['Price']) or pd.isna(row['Year']):
#         return np.nan
    
#     age = current_year - row['Year']
#     price_score = row['Price'] / 2000  
#     mileage_score = row['Mileage'] / 2500    
#     age_score = age * 5                     
    
#     weighted_sum = (0.5 * price_score) + (0.4 * mileage_score) + (0.1 * age_score)
    
#     if row['Accidents'] == 1:
#         weighted_sum += 15  
    
#     if row['Owners'] == 2:
#         weighted_sum += 5
#     elif row['Owners'] > 2:
#         weighted_sum += 10
    
#     if row['Usage'] == 0:  # Commercial usage penalty
#         weighted_sum += 10
    
#     return weighted_sum

 
# df['Score'] = df.apply(simple_scoring, axis=1)

MEDIAN_PRICE = 25000  # median price baseline
MAX_MILEAGE = 250000
MAX_AGE = 30

def enhanced_scoring(row):
    # Check essential columns early
    if pd.isna(row.get('Mileage')) or pd.isna(row.get('Year')):
        return np.nan

    age = current_year - row['Year']
    if age < 0:
        age = 0  # avoid negative age if year is in future

    # Determine price_for_score
    price = row.get('Price')
    monthly_payment = row.get('Monthly Payment')

    if not pd.isna(price):
        price_for_score = price
    elif not pd.isna(monthly_payment):
        price_for_score = monthly_payment * 60  # estimate full price (5 years)
    else:
        return np.nan  # no price info at all

    # Normalize and clamp values
    clamped_mileage = min(row['Mileage'], MAX_MILEAGE)
    clamped_age = min(age, MAX_AGE)

    # Scores (log scale for price, power scale for others)
    price_score = np.log1p(price_for_score / MEDIAN_PRICE) * 100
    mileage_score = 100 * ((clamped_mileage / MAX_MILEAGE) ** 0.8)
    age_score = 100 * ((clamped_age / MAX_AGE) ** 0.7)

    weighted_sum = (0.55 * price_score) + (0.35 * mileage_score) + (0.10 * age_score)

    # Condition adjustment
    condition_new = row.get('Condition_New', 0) == 1
    condition_certified = row.get('Condition_Certified', 0) == 1
    condition_used = row.get('Condition_Used', 0) == 1

    if condition_new:
        weighted_sum -= 20
    elif condition_certified:
        weighted_sum -= 15
    elif not condition_used:
        weighted_sum += 5  # penalty for unknown condition

    # Accidents adjustment
    accidents = row.get('Accidents', 0)
    if accidents == 1:
        weighted_sum += 10
    elif accidents > 1:
        weighted_sum += 15  # harsher penalty for multiple accidents

    # Owners adjustment (penalties scale moderately)
    owners = row.get('Owners', 1)  # default 1 if missing
    if owners == 2:
        weighted_sum += 8
    elif owners > 2:
        weighted_sum += 8 + 3 * (owners - 2)  # scaled penalty

    # Usage adjustment
    usage = row.get('Usage', 1)  # assume 1 = non-commercial, 0 = commercial
    if usage == 0:
        # More penalty for commercial, scales with age
        weighted_sum += 15 * (1 + clamped_age / MAX_AGE)

    # Mileage per year adjustment
    years_used = age if age > 0 else 1
    miles_per_year = row['Mileage'] / years_used

    if miles_per_year < 7500:
        weighted_sum -= 5  # low mileage is good
    elif miles_per_year > 15000:
        weighted_sum += 10  # high mileage is bad

    return weighted_sum

# Apply to dataframe
df['Score'] = df.apply(enhanced_scoring, axis=1)

# Create training and testing data
df = df.dropna(subset=['Monthly Payment', 'Mileage', 'Price', 'Year', 'Score'])

X = df.drop(columns=['Score'])
y = df['Score']

# Feature selection (keep features with top 10% relevance = drop bottom 90%)
selector = SelectPercentile(f_regression, percentile=50)
X_selected = selector.fit_transform(X, y)

# Get selected feature names
selected_features = [X.columns[i] for i in selector.get_support(indices=True)]
print(f"Selected {len(selected_features)} features:")
print(selected_features)

# Update feature list
model_features = selected_features
with open('model_features.json', 'w') as f:
    json.dump(model_features, f)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_selected)

joblib.dump(scaler, 'scaler.pkl')

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y.values.reshape(-1, 1), test_size=0.2, random_state=42)

# Save X_train values
X_train_df = pd.DataFrame(X_train, columns=model_features)
X_train_df.to_pickle("X_train.pkl")

# XGBoost Benchmarking
print("\nXGBoost Benchmark:")
xgb = XGBRegressor(n_estimators=1000, learning_rate=0.01, early_stopping_rounds=50, random_state=42)
xgb.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)

xgb_pred = xgb.predict(X_test)
xgb_mse = mean_squared_error(y_test, xgb_pred)
xgb_r2 = r2_score(y_test, xgb_pred)
xgb_mae = mean_absolute_error(y_test, xgb_pred)

print(f"XGBoost MSE: {xgb_mse:.2f}")
print(f"XGBoost R²: {xgb_r2:.4f}")
print(f"XGBoost MAE: {xgb_mae:.2f}")

# Scale target
y_scaler = RobustScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

joblib.dump(y_scaler, 'model_scaler.pkl')

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_scaled.reshape(-1, 1), dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_scaled.reshape(-1, 1), dtype=torch.float32)

# Neural Network Implementation

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("\nUsing device:", device)

# Dataset Setup
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Model Definition
class ImprovedMLP(nn.Module):
    def __init__(self, input_size):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.BatchNorm1d(64),
            nn.Dropout(0.2),
            nn.Linear(64, 1)
        )
    
    def forward(self, x):
        return self.net(x)

# Training with Early Stopping
model = ImprovedMLP(X_train.shape[1]).to(device)
criterion = nn.SmoothL1Loss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

best_loss = float('inf')
patience = 100
no_improve = 0

for epoch in range(200):
    model.train()
    running_loss = 0.0
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        running_loss += loss.item() * batch_X.size(0)
    
    epoch_loss = running_loss / len(train_loader.dataset)
    
    # Validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            outputs = model(batch_X)
            val_loss += criterion(outputs, batch_y).item() * batch_X.size(0)
    
    val_loss /= len(test_loader.dataset)
    
    if val_loss < best_loss:
        best_loss = val_loss
        no_improve = 0
        torch.save(model.state_dict(), 'best_car_model.pth')

    else:
        no_improve += 1
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
    
    if (epoch + 1) % 10 == 0:
        print(f"Epoch {epoch+1}: Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}")

# Load best model
model.load_state_dict(torch.load('best_car_model.pth'))
y_scaler = joblib.load('model_scaler.pkl')

# Evaluation
model.eval()
all_preds, all_targets = [], []

with torch.no_grad():
    for batch_X, batch_y in test_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        outputs = model(batch_X)
        all_preds.append(outputs.cpu())
        all_targets.append(batch_y.cpu())

predictions = torch.cat(all_preds).numpy()
targets = torch.cat(all_targets).numpy()

preds_rescaled = y_scaler.inverse_transform(predictions)
y_true_rescaled = y_scaler.inverse_transform(targets)

print("All predictions (rescaled):")
print(preds_rescaled.flatten())


mse = mean_squared_error(y_true_rescaled, preds_rescaled)
r2 = r2_score(y_true_rescaled, preds_rescaled)
mae = mean_absolute_error(y_true_rescaled, preds_rescaled)

tolerance = 1
within_tolerance = np.abs(y_true_rescaled - preds_rescaled) <= tolerance
accuracy = np.mean(within_tolerance) * 100

print("\nFinal Evaluation:")
print(f"Test MSE: {mse:.2f}")
print(f"Test R²: {r2:.4f}")
print(f"Test MAE: {mae:.2f}")
print(f"Accuracy (within ±{tolerance}): {accuracy:.2f}%")
# Out:
# Selected 1718 features:
# ['Mileage', 'Price', 'Monthly Payment', 'Year', 'Accidents', 'Owners', 'Usage', 'Age', 'MilesPerYear', 'PricePerMile', 'Condition_New', 'Condition_Other', 'Condition_Used', 'Model_Acura Integra', 'Model_Acura Integra A-SPEC', 'Model_Acura Integra A-SPEC w/ Technology', 'Model_Acura Integra A-Spec Tech Package', 'Model_Acura Integra A-Spec Technology', 'Model_Acura Integra Base', 'Model_Acura Integra Type S', 'Model_Acura Integra W/A-SPEC TECHNOLOGY PACKAGE', 'Model_Acura Integra w/A-Spec Package', 'Model_Acura MDX 3.5L w/Technology Package', 'Model_Acura MDX A-SPEC', 'Model_Acura MDX A-Spec', 'Model_Acura MDX A-Spec Package', 'Model_Acura MDX Advance', 'Model_Acura MDX SH-AWD Technology', 'Model_Acura MDX Sport Hybrid 3.0L w/Advance Package', 'Model_Acura MDX Technology', 'Model_Acura MDX Technology Package', 'Model_Acura NSX Base', 'Model_Acura NSX T', 'Model_Acura RDX', 'Model_Acura RDX A-Spec', 'Model_Acura RDX A-Spec Advance', 'Model_Acura RDX Base', 'Model_Acura RDX Technology Package', 'Model_Acura RLX Technology Package', 'Model_Acura TLX A-Spec', 'Model_Acura TLX V6 A-Spec', 'Model_Acura TLX V6 Technology & A-Spec', 'Model_Acura ZDX A-Spec', 'Model_Acura ZDX Type S', 'Model_Alfa Romeo Stelvio Base', 'Model_Alfa Romeo Stelvio Quadrifoglio Carbon', 'Model_Alfa Romeo Tonale AWD', 'Model_Alfa Romeo Tonale Base', 'Model_Alfa Romeo Tonale Ti', 'Model_Am General Hummer Wagon', 'Model_Aston Martin DB12 Coupe', 'Model_Aston Martin DB9 Volante', 'Model_Aston Martin DBS Superleggera', 'Model_Aston Martin DBS ULTIMATE 770', 'Model_Aston Martin DBS Volante', 'Model_Aston Martin DBX 707', 'Model_Aston Martin DBX SUV', 'Model_Aston Martin V12 Vanquish Base', 'Model_Aston Martin Vanquish Volante', 'Model_Aston Martin Vantage AMR PROTOTYPE', 'Model_Aston Martin Vantage Coupe', 'Model_Aston Martin Vantage Roadster', 'Model_Aston Martin Virage Base', 'Model_Audi A3 1.8T Premium', 'Model_Audi A3 2.0T Premium quattro', 'Model_Audi A4 2.0T Premium quattro', 'Model_Audi A4 45 S line Premium Plus', 'Model_Audi A4 allroad Premium Plus', 'Model_Audi A5 Sportback 45 S Line Premium Plus', 'Model_Audi A5 Sportback S-Line Premium Plus', 'Model_Audi A5 Sportback S-Line Prestige', 'Model_Audi A6 45 Sport Premium', 'Model_Audi A6 allroad 55 quattro Premium Plus', 'Model_Audi Q3 45 S line Premium', 'Model_Audi Q3 45 S line Premium Plus', 'Model_Audi Q3 Premium 45 TFSI S line quattro Tiptronic', 'Model_Audi Q3 S line Premium', 'Model_Audi Q4 e-tron Premium Plus 55 quattro', 'Model_Audi Q5 40 Premium', 'Model_Audi Q5 40 Premium Plus', 'Model_Audi Q5 45 S line Premium', 'Model_Audi Q5 45 S line Premium Plus', 'Model_Audi Q5 Premium Plus', 'Model_Audi Q5 S-Line Prestige', 'Model_Audi Q5 e 55 S line Premium Plus', 'Model_Audi Q6 e-tron Prestige', 'Model_Audi Q7 3.0T Premium Plus', 'Model_Audi Q7 3.0T Prestige', 'Model_Audi Q7 45 Premium', 'Model_Audi Q7 45 Premium Plus', 'Model_Audi Q7 55 Premium', 'Model_Audi Q7 55 Premium Plus', 'Model_Audi Q7 55 Prestige', 'Model_Audi Q7 Premium Plus', 'Model_Audi Q7 Prestige', 'Model_Audi Q7 quattro 4dr 3.0L TDI Prestige', 'Model_Audi Q8 55 Premium Plus', 'Model_Audi Q8 55 Prestige', 'Model_Audi Q8 Premium Plus', 'Model_Audi RS 3 2.5T', 'Model_Audi RS 3 TFSI quattro S tronic', 'Model_Audi RS 5', 'Model_Audi RS 5 2.9T', 'Model_Audi RS 5 4.2', 'Model_Audi RS 7 4.0T Prestige', 'Model_Audi RS 7 4.0T quattro', 'Model_Audi RS Q8 4.0T', 'Model_Audi RS Q8 4.0T quattro', 'Model_Audi RS e-tron GT quattro', 'Model_Audi S e-tron GT Premium Plus', 'Model_Audi S3 Premium Plus TFSI quattro S tronic', 'Model_Audi S5 3.0 Premium Plus', 'Model_Audi S5 Premium Plus TFSI quattro Tiptronic', 'Model_Audi S6 2.9 TFSI Prestige', 'Model_Audi S6 Premium Plus', 'Model_Audi S6 Prestige', 'Model_Audi SQ7 4.0T Premium Plus', 'Model_Audi SQ8 4.0T Premium Plus', 'Model_Audi SQ8 4.0T Prestige', 'Model_Audi SQ8 4.0T quattro Premium Plus', 'Model_Audi TT RS 2.5T', 'Model_Audi e-tron GT Premium Plus', 'Model_Audi e-tron GT Prestige', 'Model_Audi e-tron Sp ...
#
# XGBoost Benchmark:
# XGBoost MSE: 3.50
# XGBoost R²: 0.9932
# XGBoost MAE: 1.07
#
# Using device: cuda
# Epoch 10: Train Loss: 0.0674, Val Loss: 0.0780
# Epoch 20: Train Loss: 0.0437, Val Loss: 0.0735
# Epoch 30: Train Loss: 0.0337, Val Loss: 0.0569
# Epoch 40: Train Loss: 0.0305, Val Loss: 0.0458
# Epoch 50: Train Loss: 0.0278, Val Loss: 0.0471
# Epoch 60: Train Loss: 0.0247, Val Loss: 0.0438
# Epoch 70: Train Loss: 0.0275, Val Loss: 0.0423
# Epoch 80: Train Loss: 0.0234, Val Loss: 0.0419
# Epoch 90: Train Loss: 0.0228, Val Loss: 0.0406
# Epoch 100: Train Loss: 0.0223, Val Loss: 0.0430
# Epoch 110: Train Loss: 0.0221, Val Loss: 0.0398
# Epoch 120: Train Loss: 0.0219, Val Loss: 0.0434
# Epoch 130: Train Loss: 0.0202, Val Loss: 0.0416
# Epoch 140: Train Loss: 0.0196, Val Loss: 0.0392
# Epoch 150: Train Loss: 0.0199, Val Loss: 0.0407
# Epoch 160: Train Loss: 0.0210, Val Loss: 0.0399
# Epoch 170: Train Loss: 0.0190, Val Loss: 0.0388
# Epoch 180: Train Loss: 0.0195, Val Loss: 0.0420
# Epoch 190: Train Loss: 0.0193, Val Loss: 0.0425
# Epoch 200: Train Loss: 0.0174, Val Loss: 0.0416
# All predictions (rescaled):
# [49.37632  72.54057  69.922104 ... 69.93355  52.24357  66.410065]
#
# Final Evaluation:
# Test MSE: 57.43
# Test R²: 0.8881
# Test MAE: 4.43
# Accuracy (within ±1): 21.10%

# %%
# Create the LLM input processor
from transformers import pipeline
import re
import json
import random

class CarScorePredictor:
    def __init__(self):
        
        self.input_scaler = joblib.load('scaler.pkl')
        self.output_scaler = joblib.load('model_scaler.pkl')

        # Load model features
        with open('model_features.json', 'r') as f:
            self.model_features = json.load(f)

        with open('all_make_model_keys.json', 'r') as f:
            self.model_slugs = json.load(f)
        
        self.model_types = [slug.replace('_', ' ').replace('-', ' ').title() for slug in self.model_slugs]

        # Get mean values for imputation from the training data
        self.X_train_df = pd.read_pickle("X_train.pkl")
        self.default_values = self.X_train_df.mean()

        # List of known categorical fields that were one-hot encoded
        self.one_hot_prefixes = ['Condition_', 'Model_', 'Dealer_']  
        
        # Initialize the neural network
        self.model = ImprovedMLP(input_size=len(self.model_features))  
        self.model.load_state_dict(torch.load('best_car_model.pth', weights_only=True))
        self.model.to(device)
        self.model.eval()
        
        # Initialize LLM for information extraction
        self.ner_pipeline = pipeline(
            "token-classification",
            model="dslim/bert-base-NER",
            aggregation_strategy="simple"
        )
        
        # Initialize LLM for text understanding
        self.qa_pipeline = pipeline(
            "question-answering",
            model="distilbert-base-uncased-distilled-squad"
        )

    def extract_car_info(self, text):
        """Extract structured car information from natural language"""
        # Extract entities using NER
        entities = self.ner_pipeline(text)

        # Initialize default values
        car_info = {
            'Year': None,
            'Model': None,
            'Mileage': None,
            'Price': None,
            'Condition': None,
            'Dealer': None,
            'Monthly Payment': None,
            'Accidents': 0,  # Default to no accidents
            'Owners': 1,     # Default to 1 owner
            'Usage': 1       # Default to personal use (1)
        }


        # Simple regex-based extractions for numerical fields
        mileage_match = re.search(r'\b([0-9,]+)\s*(mi|miles)\b\.?', text, re.IGNORECASE)
        price_match = re.search(r'\$([0-9,]+)\b(?![a-zA-Z/]| per)', text)
        payment_match = re.search(r'\$([0-9,]+)\s*(?:/mo|per month)', text, re.IGNORECASE)
        year_match = re.search(r'\b(20\d{2}|19\d{2})\b', text)

        if mileage_match:
            car_info['Mileage'] = int(mileage_match.group(1).replace(',', ''))
        if price_match:
            car_info['Price'] = int(price_match.group(1).replace(',', ''))
        if payment_match:
            car_info['Monthly Payment'] = int(payment_match.group(1).replace(',', ''))
        if year_match:
            car_info['Year'] = int(year_match.group(0))

        # Extract accident information
        if re.search(r'accidents?|accident history', text, re.IGNORECASE):
            car_info['Accidents'] = 1

        # Extract owner count
        owners_match = re.search(r'(\d+)\s*(owners?|previous owners?)', text, re.IGNORECASE)
        if owners_match:
            car_info['Owners'] = int(owners_match.group(1))
        elif re.search(r'one\s*owner|single owner', text, re.IGNORECASE):
            car_info['Owners'] = 1
        elif re.search(r'two\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 2
        elif re.search(r'three\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 3
        elif re.search(r'four\+?\s*owners', text, re.IGNORECASE):
            car_info['Owners'] = 4

        # Extract usage type (mapped to your binary encoding)
        if re.search(r'commercial|business|fleet', text, re.IGNORECASE):
            car_info['Usage'] = 0  # Not personal use

        # Pull entities from NER
        for ent in entities:
            label = ent['entity_group']
            word = ent['word']

            if label == 'ORG':
                car_info['Dealer'] = word
            elif label == 'MISC' or label == 'PRODUCT':
                car_info['Model'] = word
            elif label == 'DATE' and not car_info['Year']:
                try:
                    car_info['Year'] = int(re.search(r'\d{4}', word).group(0))
                except:
                    pass

        # Try to find a matching model from the list
        found_model = None
        for model in self.model_types:
            pattern = re.compile(rf'\b{re.escape(model)}\b', re.IGNORECASE)
            if pattern.search(text):
                found_model = model
                break

        if found_model:
            car_info['Model'] = found_model

        # Extract sales condition like New, Used, Certified, etc.
        condition_match = re.search(r'\b(New|Used|Certified(?: Pre-Owned)?)\b', text, re.IGNORECASE)
        if condition_match:
            car_info['Condition'] = condition_match.group(1).title()

        if not car_info['Dealer']:
            dealer_match = re.search(
                r'\b(?:at dealer|dealer:|at)\s+([A-Z][\w&.,\- ]{2,100})',
                text,
                re.IGNORECASE
            )
            if dealer_match:
                # Clean extra whitespace and strip trailing punctuation
                dealer_name = dealer_match.group(1).strip().rstrip('.,')
                dealer_name = re.sub(r'\bdealer\b', '', dealer_name, flags=re.IGNORECASE).strip()
                car_info['Dealer'] = dealer_name

        return car_info
    
    def prepare_features(self, car_info):
        """Convert extracted car info into the model input vector"""
        # Initialize feature row with zeros
        feature_vector = np.zeros(len(self.model_features))
        feature_df = pd.DataFrame([feature_vector], columns=self.model_features)

        # Fill in numerical fields
        for col in ['Year', 'Mileage', 'Price', 'Monthly Payment', 'Accidents', 'Owners']:
            val = car_info.get(col)
            if val is not None:
                feature_df.at[0, col] = val
            else:
                feature_df.at[0, col] = self.default_values[col]

        # Fill in one-hot fields
        for prefix in self.one_hot_prefixes:
            value = car_info.get(prefix)
            if value is not None:
                encoded = f"{prefix}_{value}"
                if encoded in self.model_features:
                    feature_df.at[0, encoded] = 1.0

        # Apply input scaling
        scaled_features = self.input_scaler.transform(feature_df.values)
        
        # Convert to tensor
        return torch.tensor(scaled_features, dtype=torch.float32).to(device)

    
    def predict_score(self, text_input):
        """Main prediction pipeline"""
        # Extract information from text
        car_info = self.extract_car_info(text_input)
        print("Extracted car info:", car_info)
        
        # Prepare features for model
        features_tensor = self.prepare_features(car_info)
        
        # Make prediction
        with torch.no_grad():
            prediction = self.model(features_tensor)
            score = self.output_scaler.inverse_transform(prediction.cpu().numpy().reshape(-1, 1))
        
        return score[0][0]

# Example usage
if __name__ == "__main__":
    predictor = CarScorePredictor()

    # Define options for different fields
    years = [str(y) for y in range(1998, 2023)]

    # Extract model names from the one-hot encoded features (removing "Model_" prefix)
    sample_models = [feature.replace("Model_", "") for feature in model_features if feature.startswith("Model_")]
    mileages = [f"{x:,}" for x in range(0, 250001, 5000)]
    prices = [f"${x:,}" for x in range(4000, 120001, 2000)]
    conditions = [feature.replace("Condition_", "") for feature in model_features if feature.startswith("Condition_")]
    dealers = [feature.replace("Dealer_", "") for feature in model_features if feature.startswith("Dealer_")]
    payments = [f"${x:,}" for x in range(120, 3001, 50)]
    
    # Options for additional features
    accident_options = ["no accidents", "accident reported", "clean history", "1 accident", "accident history"]
    owner_options = ["1 owner", "2 owners", "3 owners", "4+ owners", "single owner", "one previous owner"]
    usage_options = ["private use", "commercial use", "fleet use", "personal use", "business use"]

    # Create templates with varying levels of information
    basic_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition",
        "{model} from {year} with {mileage} miles, {price}",
        "Dealer: {dealer}. {year} {model}, {mileage} miles, {price}",
        "Looking at a {year} {model}, {condition} condition, {price}"
    ]
    
    intermediate_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition, {owner}",
        "{model} ({year}), {mileage} miles, {price}, {usage}, {accident}",
        "Found a {year} {model}, {condition} condition, {price}, {owner}, {accident}",
        "{year} {model}, {mileage} miles, {price}, {usage}, dealer: {dealer}"
    ]
    
    full_info_templates = [
        "{year} {model}, {mileage} miles, {price}, {condition} condition, {owner}, {accident}, {usage}",
        "Dealer: {dealer}. {year} {model}, {mileage} miles, {price}, {condition}, {owner}, {usage}, {accident}",
        "Complete info: {year} {model}, {mileage} miles, {price}, {condition}, {owner}, {accident}, {usage}, dealer: {dealer}"
    ]

    # Combine all templates
    all_templates = basic_templates + intermediate_templates + full_info_templates

    # Generate 100 diverse test queries with varying information completeness
    test_queries = []
    for _ in range(100):
        template = random.choice(all_templates)
        
        # For basic templates, don't include all optional features
        if template in basic_templates:
            query = template.format(
                year=random.choice(years),
                model=random.choice(sample_models),
                mileage=random.choice(mileages),
                price=random.choice(prices),
                condition=random.choice(conditions),
                dealer=random.choice(dealers)
            )
        else:
            query = template.format(
                year=random.choice(years),
                model=random.choice(sample_models),
                mileage=random.choice(mileages),
                price=random.choice(prices),
                condition=random.choice(conditions),
                dealer=random.choice(dealers),
                accident=random.choice(accident_options),
                owner=random.choice(owner_options),
                usage=random.choice(usage_options)
            )
        test_queries.append(query)

    # Add some manual examples that cover edge cases
    test_queries.extend([
        "2021 Toyota Camry with 35,000 miles for $25,000 in used condition from AutoNation, no accidents, 1 owner",
        "2019 Honda Accord, 75,000 miles, $18,500, used condition, personal use",
        "Tesla Model 3 2022 with 12,000 miles priced at $42,000, clean history",
        "Ford F-150 2017, 120,000 miles, $22,999, used condition, commercial use, accident reported",
        "2018 Nissan Rogue, $16,500, 85,000 miles, used condition, 3 owners",
        "2018 Subaru Baja, $500 per month, 2,000 miles, used condition, 1 owner",
        "2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history"
    ])
    
    min_score = 1000 # Will store smallest tuple query
    min_query = ""

    # Test the predictor with sample queries
    for i, query in enumerate(test_queries):  # Just test first 10 for demonstration
        try:
            score = predictor.predict_score(query)

            if (score < min_score) and (query != ""):
                min_score = score
                min_query = query
            
            print(f"Query {i+1}: {query}")
            print(f"Predicted Score: {score:.2f}\n")
        except Exception as e:
            print(f"Error processing query: {query}")
            print(f"Error: {str(e)}\n")
    
    print(f"Min Query: {min_query}")
    print(f"Min Score: {min_score:.2f}\n")
# Out:
# Extracted car info: {'Year': 2000, 'Model': 'Dodge Durango', 'Mileage': 135000, 'Price': 80000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 1: Dodge Durango SRT Hellcat (2000), 135,000 miles, $80,000, business use, accident history
# Predicted Score: 67.51
#
# Extracted car info: {'Year': 1999, 'Model': 'Acura Mdx', 'Mileage': 115000, 'Price': 74000, 'Condition': None, 'Dealer': 'AWD Technology', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 2: 1999 Acura MDX SH-AWD Technology, 115,000 miles, $74,000, commercial use, dealer: Patty
# Predicted Score: 56.05
#
# Extracted car info: {'Year': 2008, 'Model': 'Subaru Crosstrek', 'Mileage': 90000, 'Price': 84000, 'Condition': 'Used', 'Dealer': '##tre', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 3: 2008 Subaru Crosstrek Base, 90,000 miles, $84,000, Used condition, 2 owners, accident history, personal use
# Predicted Score: 69.95
#
# Extracted car info: {'Year': 2020, 'Model': 'Lamborghini Huracan', 'Mileage': 35000, 'Price': 74000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 4: 2020 Lamborghini Huracan STO Coupe, 35,000 miles, $74,000, Other condition, single owner, accident reported, personal use
# Predicted Score: 58.75
#
# Extracted car info: {'Year': 1999, 'Model': 'Bmw X4', 'Mileage': 150000, 'Price': 78000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 5: BMW X4 M40I from 1999 with 150,000 miles, $78,000
# Predicted Score: 59.16
#
# Extracted car info: {'Year': 2003, 'Model': 'Chevrolet Silverado 1500', 'Mileage': None, 'Price': 84000, 'Condition': 'New', 'Dealer': 'a 2003 Chevrolet Silverado 1500 Work Truck, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 6: Looking at a 2003 Chevrolet Silverado 1500 Work Truck, New condition, $84,000
# Predicted Score: 54.29
#
# Extracted car info: {'Year': 2008, 'Model': 'Hyundai Elantra', 'Mileage': None, 'Price': 82000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 7: Found a 2008 Hyundai Elantra SEL, Other condition, $82,000, one previous owner, accident history
# Predicted Score: 61.79
#
# Extracted car info: {'Year': 2021, 'Model': 'Mercedes - Benz CLA', 'Mileage': None, 'Price': 30000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 8: Found a 2021 Mercedes-Benz CLA-Class Base, New condition, $30,000, 4+ owners, accident history
# Predicted Score: 43.93
#
# Extracted car info: {'Year': 2022, 'Model': 'Mitsubishi Lancer', 'Mileage': None, 'Price': 12000, 'Condition': None, 'Dealer': 'a 2022 Mitsubishi Lancer Evolution GSR, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 9: Looking at a 2022 Mitsubishi Lancer Evolution GSR, Other condition, $12,000
# Predicted Score: 34.50
#
# Extracted car info: {'Year': 2011, 'Model': 'Land Rover Defender', 'Mileage': 35000, 'Price': 42000, 'Condition': None, 'Dealer': 'CarMax Charleston', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 10: 2011 Land Rover Defender 110 P400 X, 35,000 miles, $42,000, fleet use, dealer: CarMax Charleston
# Predicted Score: 40.26
#
# Extracted car info: {'Year': 2006, 'Model': 'Class', 'Mileage': 25000, 'Price': 94000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 11: 2006 Mercedes-Benz SL-Class SL 63 AMG 2dr Convertible, 25,000 miles, $94,000, New condition
# Predicted Score: 58.30
#
# Extracted car info: {'Year': 2018, 'Model': 'Ford Roadster', 'Mileage': 140000, 'Price': 118000, 'Condition': None, 'Dealer': 'carneed', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 12: 2018 Ford Roadster, 140,000 miles, $118,000, private use, dealer: carneed
# Predicted Score: 67.19
#
# Extracted car info: {'Year': 2009, 'Model': 'Cadillac Ats', 'Mileage': 150000, 'Price': 8000, 'Condition': None, 'Dealer': 'Brian. 2009 Cadillac ATS 2.0L Turbo Premium, 150,000 miles', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 13: Dealer: Brian. 2009 Cadillac ATS 2.0L Turbo Premium, 150,000 miles, $8,000
# Predicted Score: 38.38
#
# Extracted car info: {'Year': 2008, 'Model': 'Dodge Challenger', 'Mileage': 220000, 'Price': 90000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 14: Dodge Challenger SRT 392 (2008), 220,000 miles, $90,000, personal use, accident history
# Predicted Score: 71.69
#
# Extracted car info: {'Year': 2000, 'Model': 'Rolls - Royce Wraith Coupe', 'Mileage': 180000, 'Price': 74000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 15: 2000 Rolls-Royce Wraith Coupe, 180,000 miles, $74,000, Used condition, 1 owner
# Predicted Score: 58.94
#
# Extracted car info: {'Year': 2015, 'Model': 'Toyota Corolla', 'Mileage': None, 'Price': 48000, 'Condition': 'Used', 'Dealer': 'a 2015 Toyota Corolla Cross Hybrid Nightshade Edition, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 16: Looking at a 2015 Toyota Corolla Cross Hybrid Nightshade Edition, Used condition, $48,000
# Predicted Score: 40.19
#
# Extracted car info: {'Year': 2006, 'Model': 'Cadillac Escalade', 'Mileage': 200000, 'Price': 42000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 17: Cadillac Escalade Premium Luxury Platinum (2006), 200,000 miles, $42,000, private use, 1 accident
# Predicted Score: 56.71
#
# Extracted car info: {'Year': 2006, 'Model': 'Jeep Wrangler', 'Mileage': 125000, 'Price': 18000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 18: 2006 Jeep Wrangler Unlimited Freedom 4X4, 125,000 miles, $18,000, Other condition, 4+ owners
# Predicted Score: 39.55
#
# Extracted car info: {'Year': 1999, 'Model': 'Toyota Camry', 'Mileage': 90000, 'Price': 44000, 'Condition': 'New', 'Dealer': 'Phillips Chevrolet', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 19: Dealer: Phillips Chevrolet of Lansing. 1999 Toyota Camry Hybrid SE, 90,000 miles, $44,000, New, one previous owner, commercial use, accident reported
# Predicted Score: 53.16
#
# Extracted car info: {'Year': 2006, 'Model': 'Chevrolet Impala', 'Mileage': None, 'Price': 114000, 'Condition': 'Used', 'Dealer': 'a 2006 Chevrolet Impala Limited LTZ, Used condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 20: Looking at a 2006 Chevrolet Impala Limited LTZ, Used condition, $114,000
# Predicted Score: 63.34
#
# Extracted car info: {'Year': 2016, 'Model': 'Chevrolet Corvette', 'Mileage': 180000, 'Price': 118000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 21: 2016 Chevrolet Corvette Stingray 1LT, 180,000 miles, $118,000, New condition
# Predicted Score: 68.16
#
# Extracted car info: {'Year': 2013, 'Model': 'Volvo Xc40', 'Mileage': 30000, 'Price': 48000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 22: 2013 Volvo XC40 Plus Dark Theme, 30,000 miles, $48,000, New condition
# Predicted Score: 41.23
#
# Extracted car info: {'Year': 2014, 'Model': 'Mclaren 600Lt', 'Mileage': 200000, 'Price': 72000, 'Condition': 'Used', 'Dealer': 'CarMax', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 23: Complete info: 2014 McLaren 600LT MSO Burton Blue! Tons of Carbon Fiber! Carbon Ceramic Brakes! Loaded!, 200,000 miles, $72,000, Used, 2 owners, accident history, personal use, dealer: CarMax El Paso West
# Predicted Score: 69.60
#
# Extracted car info: {'Year': 2009, 'Model': 'Ferrari F40', 'Mileage': 210000, 'Price': 64000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 24: 2009 Ferrari F40 F40, 210,000 miles, $64,000, New condition
# Predicted Score: 54.84
#
# Extracted car info: {'Year': 2022, 'Model': 'Land Rover Defender', 'Mileage': 215000, 'Price': 26000, 'Condition': None, 'Dealer': 'Land Rover', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 25: Land Rover Defender 130 P300 S (2022), 215,000 miles, $26,000, personal use, accident reported
# Predicted Score: 51.55
#
# Extracted car info: {'Year': 2007, 'Model': 'Chrysler Voyager', 'Mileage': None, 'Price': 10000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 26: Found a 2007 Chrysler Voyager LX, Other condition, $10,000, 1 owner, no accidents
# Predicted Score: 41.05
#
# Extracted car info: {'Year': 2010, 'Model': 'Infiniti Qx80', 'Mileage': 20000, 'Price': 70000, 'Condition': None, 'Dealer': 'CarMax Charleston', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 27: 2010 INFINITI QX80 Sensory, 20,000 miles, $70,000, business use, dealer: CarMax Charleston
# Predicted Score: 48.25
#
# Extracted car info: {'Year': 2020, 'Model': 'Mazda Mazda3', 'Mileage': None, 'Price': 16000, 'Condition': 'New', 'Dealer': 'a 2020 Mazda Mazda3 Premium Plus, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 28: Looking at a 2020 Mazda Mazda3 Premium Plus, New condition, $16,000
# Predicted Score: 35.01
#
# Extracted car info: {'Year': 2006, 'Model': 'Ferrari Portofino', 'Mileage': 190000, 'Price': 54000, 'Condition': None, 'Dealer': 'Ferrari Porto', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 29: Dealer: Maserati of Naperville. 2006 Ferrari Portofino Base, 190,000 miles, $54,000
# Predicted Score: 50.88
#
# Extracted car info: {'Year': 2011, 'Model': 'Land Rover Lr3', 'Mileage': 95000, 'Price': 82000, 'Condition': 'Used', 'Dealer': 'Land Rover', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 30: 2011 Land Rover LR3 HSE, 95,000 miles, $82,000, Used condition, 4+ owners, 1 accident, private use
# Predicted Score: 65.04
#
# Extracted car info: {'Year': 2019, 'Model': 'Nissan Rogue', 'Mileage': None, 'Price': 60000, 'Condition': 'New', 'Dealer': 'a 2019 Nissan Rogue Select S, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 31: Looking at a 2019 Nissan Rogue Select S, New condition, $60,000
# Predicted Score: 42.83
#
# Extracted car info: {'Year': 2018, 'Model': 'Audi Q7', 'Mileage': 60000, 'Price': 74000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 32: Audi Q7 quattro 4dr 3.0L TDI Prestige from 2018 with 60,000 miles, $74,000
# Predicted Score: 49.94
#
# Extracted car info: {'Year': 2020, 'Model': 'Benz AMG C S', 'Mileage': None, 'Price': 14000, 'Condition': None, 'Dealer': 'a 2020 Mercedes-Benz AMG C S, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 33: Looking at a 2020 Mercedes-Benz AMG C S, Other condition, $14,000
# Predicted Score: 34.77
#
# Extracted car info: {'Year': 2019, 'Model': 'Mercedes - Benz GLC', 'Mileage': 10000, 'Price': 108000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 34: 2019 Mercedes-Benz GLC 300, 10,000 miles, $108,000, New condition, single owner
# Predicted Score: 60.77
#
# Extracted car info: {'Year': 1998, 'Model': 'Genesis G80', 'Mileage': None, 'Price': 24000, 'Condition': None, 'Dealer': 'a 1998 Genesis G80 3.5T, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 35: Looking at a 1998 Genesis G80 3.5T, Other condition, $24,000
# Predicted Score: 37.44
#
# Extracted car info: {'Year': 2016, 'Model': 'Mercedes - Benz C - Class', 'Mileage': 30000, 'Price': 84000, 'Condition': None, 'Dealer': 'CarMax Live Oak', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 36: Dealer: CarMax Live Oak. 2016 Mercedes-Benz C-Class, 30,000 miles, $84,000
# Predicted Score: 53.09
#
# Extracted car info: {'Year': 2016, 'Model': 'Bmw 135', 'Mileage': 195000, 'Price': 116000, 'Condition': None, 'Dealer': 'Castle Mazda Downers Grove', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 0}
# Query 37: Dealer: Castle Mazda Downers Grove. 2016 BMW 135 i, 195,000 miles, $116,000, Other, 3 owners, business use, clean history
# Predicted Score: 74.35
#
# Extracted car info: {'Year': 2014, 'Model': 'Audi S5', 'Mileage': None, 'Price': 104000, 'Condition': 'New', 'Dealer': 'a 2014 Audi S5 Premium Plus TFSI quattro Tiptronic, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 38: Looking at a 2014 Audi S5 Premium Plus TFSI quattro Tiptronic, New condition, $104,000
# Predicted Score: 59.57
#
# Extracted car info: {'Year': 2001, 'Model': 'Audi S6', 'Mileage': 110000, 'Price': 6000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 39: Audi S6 2.9 TFSI Prestige from 2001 with 110,000 miles, $6,000
# Predicted Score: 37.60
#
# Extracted car info: {'Year': 2018, 'Model': 'Chevrolet Spark', 'Mileage': 155000, 'Price': 62000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 40: Chevrolet Spark EV LT from 2018 with 155,000 miles, $62,000
# Predicted Score: 49.43
#
# Extracted car info: {'Year': 2018, 'Model': 'Subaru Crosstrek', 'Mileage': 240000, 'Price': 114000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 41: Subaru Crosstrek Premium from 2018 with 240,000 miles, $114,000
# Predicted Score: 68.96
#
# Extracted car info: {'Year': 2011, 'Model': 'Kia Telluride', 'Mileage': 225000, 'Price': 94000, 'Condition': 'Used', 'Dealer': 'Continental Ferrari', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 42: Complete info: 2011 Kia Telluride SX-Prestige X-Pro, 225,000 miles, $94,000, Used, 1 owner, accident reported, personal use, dealer: Continental Ferrari
# Predicted Score: 72.37
#
# Extracted car info: {'Year': 2000, 'Model': 'Bmw X5', 'Mileage': 90000, 'Price': 118000, 'Condition': 'Used', 'Dealer': 'Webb Hyundai Highland', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 43: Dealer: Webb Hyundai Highland. 2000 BMW X5 sDrive40i, 90,000 miles, $118,000, Used, one previous owner, business use, 1 accident
# Predicted Score: 73.59
#
# Extracted car info: {'Year': 2010, 'Model': 'Kia Seltos', 'Mileage': 80000, 'Price': 52000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 44: 2010 Kia Seltos S, 80,000 miles, $52,000, New condition, single owner
# Predicted Score: 44.44
#
# Extracted car info: {'Year': 1998, 'Model': 'Land Rover Defender', 'Mileage': 220000, 'Price': 78000, 'Condition': None, 'Dealer': 'Rover', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 45: Land Rover Defender 110 P525 Carpathian Edition from 1998 with 220,000 miles, $78,000
# Predicted Score: 62.80
#
# Extracted car info: {'Year': 2004, 'Model': 'Bmw M850', 'Mileage': None, 'Price': 58000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 46: Found a 2004 BMW M850 I xDrive, Other condition, $58,000, 2 owners, accident history
# Predicted Score: 58.22
#
# Extracted car info: {'Year': 2020, 'Model': 'Buick Encore', 'Mileage': 90000, 'Price': 44000, 'Condition': None, 'Dealer': '##ffinity Auto Sales', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 47: Dealer: Affinity Auto Sales. 2020 Buick Encore GX Essence, 90,000 miles, $44,000
# Predicted Score: 41.63
#
# Extracted car info: {'Year': 2013, 'Model': 'Ford Expedition', 'Mileage': 70000, 'Price': 112000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 48: Ford Expedition XLT from 2013 with 70,000 miles, $112,000
# Predicted Score: 64.35
#
# Extracted car info: {'Year': 2020, 'Model': 'Transit', 'Mileage': None, 'Price': 98000, 'Condition': None, 'Dealer': 'Ford', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 49: Looking at a 2020 Ford Transit-250 Base, Other condition, $98,000
# Predicted Score: 56.83
#
# Extracted car info: {'Year': 2014, 'Model': 'Land Rover Range Rover', 'Mileage': 235000, 'Price': 58000, 'Condition': None, 'Dealer': 'Land Rover', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 50: Dealer: Pro Cars USA Inc. 2014 Land Rover Range Rover Sport Autobiography, 235,000 miles, $58,000
# Predicted Score: 53.00
#
# Extracted car info: {'Year': 2022, 'Model': 'Hyundai Sonata', 'Mileage': 85000, 'Price': 30000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 51: Hyundai Sonata GLS (2022), 85,000 miles, $30,000, private use, accident reported
# Predicted Score: 46.51
#
# Extracted car info: {'Year': 2012, 'Model': 'Ineos Grenadier', 'Mileage': 155000, 'Price': 12000, 'Condition': None, 'Dealer': '##rts', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 52: 2012 INEOS Grenadier Fieldmaster, 155,000 miles, $12,000, commercial use, dealer: Glenview Luxury Imports
# Predicted Score: 38.84
#
# Extracted car info: {'Year': 2005, 'Model': 'Aston Martin Vanquish', 'Mileage': None, 'Price': 72000, 'Condition': None, 'Dealer': 'a 2005 Aston Martin Vanquish Volante, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 53: Looking at a 2005 Aston Martin Vanquish Volante, Other condition, $72,000
# Predicted Score: 49.17
#
# Extracted car info: {'Year': 2008, 'Model': 'Pontiac Firebird Hatchback', 'Mileage': 160000, 'Price': 114000, 'Condition': None, 'Dealer': '##ey Webb Ford', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 54: 2008 Pontiac Firebird Hatchback, 160,000 miles, $114,000, commercial use, dealer: Packey Webb Ford
# Predicted Score: 67.44
#
# Extracted car info: {'Year': 1998, 'Model': 'Ferrari California', 'Mileage': 95000, 'Price': 90000, 'Condition': None, 'Dealer': 'Baha Auto Sales', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 55: Dealer: Baha Auto Sales. 1998 Ferrari California T, 95,000 miles, $90,000
# Predicted Score: 60.78
#
# Extracted car info: {'Year': 2008, 'Model': 'Acura Mdx', 'Mileage': 185000, 'Price': 106000, 'Condition': None, 'Dealer': 'Acura MDX Technology', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 56: Acura MDX Technology from 2008 with 185,000 miles, $106,000
# Predicted Score: 66.62
#
# Extracted car info: {'Year': 2000, 'Model': 'Porsche 911', 'Mileage': 15000, 'Price': 36000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 57: 2000 Porsche 911 Carrera 4S, 15,000 miles, $36,000, Used condition
# Predicted Score: 39.69
#
# Extracted car info: {'Year': 2009, 'Model': None, 'Mileage': 175000, 'Price': 114000, 'Condition': None, 'Dealer': 'Honda', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 58: Dealer: Alfa Romeo of Naperville. 2009 Honda HR-V EX, 175,000 miles, $114,000
# Predicted Score: 67.75
#
# Extracted car info: {'Year': 2018, 'Model': 'Class S', 'Mileage': 205000, 'Price': 48000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 1}
# Query 59: 2018 Mercedes-Benz S-Class S 63 E AMG, 205,000 miles, $48,000, Used condition, 3 owners
# Predicted Score: 56.54
#
# Extracted car info: {'Year': 2005, 'Model': 'Ram 2500', 'Mileage': 190000, 'Price': 36000, 'Condition': None, 'Dealer': 'RAM', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 60: RAM 2500 Tradesman (2005), 190,000 miles, $36,000, business use, clean history
# Predicted Score: 46.10
#
# Extracted car info: {'Year': 2014, 'Model': 'Bentley Continental', 'Mileage': 45000, 'Price': 82000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 61: Bentley Continental GT Mulliner V8 from 2014 with 45,000 miles, $82,000
# Predicted Score: 53.22
#
# Extracted car info: {'Year': 2017, 'Model': 'Maserati Grecale', 'Mileage': 90000, 'Price': 72000, 'Condition': None, 'Dealer': '##gor', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 62: Maserati Grecale Folgore from 2017 with 90,000 miles, $72,000
# Predicted Score: 50.57
#
# Extracted car info: {'Year': 1999, 'Model': 'Acura Nsx', 'Mileage': 165000, 'Price': 58000, 'Condition': 'New', 'Dealer': 'INFINITI', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 63: Dealer: INFINITI of Naperville. 1999 Acura NSX T, 165,000 miles, $58,000, New, single owner, business use, accident history
# Predicted Score: 61.49
#
# Extracted car info: {'Year': 1999, 'Model': 'Mclaren 600Lt', 'Mileage': 105000, 'Price': 64000, 'Condition': 'Used', 'Dealer': 'Circle Buick GMC', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 64: Complete info: 1999 McLaren 600LT Coupe HUGE MSRP! MSO Ceramic Grey! MSO Clubsport Pack! TONS of Carbon! PPF!, 105,000 miles, $64,000, Used, one previous owner, accident history, private use, dealer: Circle Buick GMC
# Predicted Score: 60.93
#
# Extracted car info: {'Year': 2018, 'Model': 'Audi Rs 7', 'Mileage': 205000, 'Price': 56000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 1}
# Query 65: 2018 Audi RS 7 4.0T quattro, 205,000 miles, $56,000, Used condition, 3 owners
# Predicted Score: 58.71
#
# Extracted car info: {'Year': 2006, 'Model': 'Tesla Model Y', 'Mileage': 140000, 'Price': 8000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 66: Tesla Model Y Long Range Dual Motor All-Wheel Drive (2006), 140,000 miles, $8,000, commercial use, clean history
# Predicted Score: 38.35
#
# Extracted car info: {'Year': 2014, 'Model': 'Volkswagen Tiguan', 'Mileage': 195000, 'Price': 92000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 67: 2014 Volkswagen Tiguan 2.0T SE, 195,000 miles, $92,000, Other condition, single owner, no accidents, private use
# Predicted Score: 71.13
#
# Extracted car info: {'Year': 2007, 'Model': 'Ferrari F12Berlinetta', 'Mileage': 25000, 'Price': 16000, 'Condition': 'Used', 'Dealer': 'GMC Buick', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 0}
# Query 68: Complete info: 2007 Ferrari F12berlinetta Base, 25,000 miles, $16,000, Used, 2 owners, accident reported, commercial use, dealer: Lochmandy Motor Sales, Inc. GMC Buick
# Predicted Score: 47.53
#
# Extracted car info: {'Year': 2003, 'Model': 'Audi Q5', 'Mileage': 85000, 'Price': 92000, 'Condition': None, 'Dealer': 'Chicago Cars US', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 69: 2003 Audi Q5 Premium Plus, 85,000 miles, $92,000, business use, dealer: Chicago Cars US
# Predicted Score: 60.30
#
# Extracted car info: {'Year': 2021, 'Model': 'Gmc Hummer Ev', 'Mileage': 250000, 'Price': 66000, 'Condition': None, 'Dealer': 'GMC', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 70: Dealer: CarMax Palm Desert. 2021 GMC HUMMER EV 3X, 250,000 miles, $66,000
# Predicted Score: 55.41
#
# Extracted car info: {'Year': 2009, 'Model': 'Bmw 340', 'Mileage': None, 'Price': 24000, 'Condition': None, 'Dealer': 'a 2009 BMW 340 i, Other condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 71: Looking at a 2009 BMW 340 i, Other condition, $24,000
# Predicted Score: 36.49
#
# Extracted car info: {'Year': 2008, 'Model': 'Acura Tlx', 'Mileage': None, 'Price': 58000, 'Condition': 'New', 'Dealer': 'a 2008 Acura TLX V6 A-Spec, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 72: Looking at a 2008 Acura TLX V6 A-Spec, New condition, $58,000
# Predicted Score: 43.52
#
# Extracted car info: {'Year': 2003, 'Model': 'Audi Q5', 'Mileage': 240000, 'Price': 22000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 2, 'Usage': 1}
# Query 73: 2003 Audi Q5 S-Line Prestige, 240,000 miles, $22,000, Used condition, 2 owners
# Predicted Score: 49.65
#
# Extracted car info: {'Year': 1998, 'Model': 'Kia Carnival', 'Mileage': 195000, 'Price': 40000, 'Condition': 'Used', 'Dealer': 'S & M Auto', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 0}
# Query 74: Complete info: 1998 Kia Carnival Hybrid SX, 195,000 miles, $40,000, Used, 3 owners, clean history, fleet use, dealer: S&M Auto Sales
# Predicted Score: 57.14
#
# Extracted car info: {'Year': 2013, 'Model': 'Gmc Terrain', 'Mileage': 235000, 'Price': 66000, 'Condition': None, 'Dealer': 'Highline Auto Sales', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 0}
# Query 75: Complete info: 2013 GMC Terrain Elevation, 235,000 miles, $66,000, Other, 2 owners, accident history, fleet use, dealer: Highline Auto Sales
# Predicted Score: 69.00
#
# Extracted car info: {'Year': 2018, 'Model': 'Acura Mdx', 'Mileage': 20000, 'Price': 118000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 76: 2018 Acura MDX A-Spec, 20,000 miles, $118,000, Used condition, 4+ owners, accident history, fleet use
# Predicted Score: 72.39
#
# Extracted car info: {'Year': 2013, 'Model': 'Ferrari F8 Spider', 'Mileage': 120000, 'Price': 68000, 'Condition': None, 'Dealer': 'CarMax Memphis', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 77: Complete info: 2013 Ferrari F8 Spider Convertible, 120,000 miles, $68,000, Other, one previous owner, clean history, fleet use, dealer: CarMax Memphis
# Predicted Score: 51.06
#
# Extracted car info: {'Year': 2018, 'Model': 'Chevrolet Suburban', 'Mileage': 30000, 'Price': 20000, 'Condition': None, 'Dealer': 'Chevrolet', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 78: Chevrolet Suburban LT from 2018 with 30,000 miles, $20,000
# Predicted Score: 36.19
#
# Extracted car info: {'Year': 2004, 'Model': 'Kia K5', 'Mileage': 230000, 'Price': 14000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 79: Kia K5 GT (2004), 230,000 miles, $14,000, personal use, no accidents
# Predicted Score: 51.71
#
# Extracted car info: {'Year': 1999, 'Model': 'Volkswagen Routan', 'Mileage': 45000, 'Price': 80000, 'Condition': None, 'Dealer': 'SE', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 80: Dealer: CarMax Cy-Fair. 1999 Volkswagen Routan SE, 45,000 miles, $80,000
# Predicted Score: 55.24
#
# Extracted car info: {'Year': 2010, 'Model': 'Gmc Sierra 1500', 'Mileage': 75000, 'Price': 72000, 'Condition': None, 'Dealer': 'Patrick Hyundai of Schaumburg', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 81: 2010 GMC Sierra 1500 SLT, 75,000 miles, $72,000, business use, dealer: Patrick Hyundai of Schaumburg
# Predicted Score: 51.27
#
# Extracted car info: {'Year': 2001, 'Model': 'Audi A4', 'Mileage': 40000, 'Price': 16000, 'Condition': None, 'Dealer': '##yundai', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 82: 2001 Audi A4 45 S line Premium Plus, 40,000 miles, $16,000, business use, dealer: Hyundai of Lincolnwood
# Predicted Score: 37.03
#
# Extracted car info: {'Year': 2003, 'Model': 'Buick Enclave', 'Mileage': None, 'Price': 94000, 'Condition': 'New', 'Dealer': 'a 2003 Buick Enclave Premium FWD, New condition', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 83: Looking at a 2003 Buick Enclave Premium FWD, New condition, $94,000
# Predicted Score: 57.80
#
# Extracted car info: {'Year': 2017, 'Model': 'Mercedes - Benz AMG GT', 'Mileage': 105000, 'Price': 32000, 'Condition': None, 'Dealer': 'Oakbrook Toyota', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 84: Dealer: Oakbrook Toyota in Westmont. 2017 Mercedes-Benz AMG GT 53 Base, 105,000 miles, $32,000
# Predicted Score: 40.16
#
# Extracted car info: {'Year': 2002, 'Model': 'Lamborghini Urus', 'Mileage': 115000, 'Price': 96000, 'Condition': None, 'Dealer': '##or', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 85: Lamborghini Urus Full ADAS Package Advanced 3D Sound Full Electric Seats Pano Roof (2002), 115,000 miles, $96,000, private use, accident history
# Predicted Score: 70.37
#
# Extracted car info: {'Year': 2004, 'Model': 'Cadillac Ct6', 'Mileage': 210000, 'Price': 70000, 'Condition': None, 'Dealer': 'Dick Wickstrom Chevrolet. 2004 Cadillac CT6 Platinum, 210,000 miles', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 86: Dealer: Dick Wickstrom Chevrolet. 2004 Cadillac CT6 Platinum, 210,000 miles, $70,000
# Predicted Score: 58.13
#
# Extracted car info: {'Year': 2018, 'Model': 'Audi A4', 'Mileage': 210000, 'Price': 16000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 87: Audi A4 45 S line Premium Plus from 2018 with 210,000 miles, $16,000
# Predicted Score: 41.02
#
# Extracted car info: {'Year': 2005, 'Model': 'Lexus Is 300', 'Mileage': 100000, 'Price': 36000, 'Condition': None, 'Dealer': 'Warner Robins', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 88: 2005 Lexus IS 300 Base, 100,000 miles, $36,000, business use, dealer: CarMax Warner Robins
# Predicted Score: 42.09
#
# Extracted car info: {'Year': 2014, 'Model': 'Ford Explorer', 'Mileage': None, 'Price': 100000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 2, 'Usage': 1}
# Query 89: Found a 2014 Ford Explorer Active, Used condition, $100,000, 2 owners, accident history
# Predicted Score: 71.28
#
# Extracted car info: {'Year': 2000, 'Model': 'Nissan Maxima', 'Mileage': 110000, 'Price': 90000, 'Condition': None, 'Dealer': 'Auto', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 90: Dealer: Exclusive Auto Haus. 2000 Nissan Maxima 3.5 Platinum, 110,000 miles, $90,000
# Predicted Score: 61.07
#
# Extracted car info: {'Year': 2014, 'Model': 'Audi A6', 'Mileage': 95000, 'Price': 64000, 'Condition': 'Used', 'Dealer': 'Chevrolet of Naper', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 91: Complete info: 2014 Audi A6 45 Sport Premium, 95,000 miles, $64,000, Used, 4+ owners, accident reported, fleet use, dealer: Chevrolet of Naperville
# Predicted Score: 57.93
#
# Extracted car info: {'Year': 2019, 'Model': 'Sportback Pre', 'Mileage': 35000, 'Price': 118000, 'Condition': None, 'Dealer': 'Audi', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 92: Audi e-tron Sportback Premium (2019), 35,000 miles, $118,000, personal use, clean history
# Predicted Score: 64.56
#
# Extracted car info: {'Year': 2015, 'Model': 'Porsche 911', 'Mileage': 30000, 'Price': 114000, 'Condition': None, 'Dealer': 'Sergey. 2015 Porsche 911 Carrera GTS, 30,000 miles', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 93: Dealer: Sergey. 2015 Porsche 911 Carrera GTS, 30,000 miles, $114,000
# Predicted Score: 63.60
#
# Extracted car info: {'Year': 2006, 'Model': 'Subaru Forester', 'Mileage': 175000, 'Price': 56000, 'Condition': None, 'Dealer': 'Subaru Forester Limited', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 94: Subaru Forester Limited from 2006 with 175,000 miles, $56,000
# Predicted Score: 50.74
#
# Extracted car info: {'Year': 2021, 'Model': 'Chevrolet Traverse', 'Mileage': 195000, 'Price': 76000, 'Condition': None, 'Dealer': 'Ultimo Motors North Shore', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 95: Dealer: Ultimo Motors North Shore. 2021 Chevrolet Traverse LT Cloth, 195,000 miles, $76,000, Other, 4+ owners, fleet use, no accidents
# Predicted Score: 65.69
#
# Extracted car info: {'Year': 2003, 'Model': 'Jeep Grand Cherokee', 'Mileage': 120000, 'Price': 24000, 'Condition': 'New', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 96: 2003 Jeep Grand Cherokee 4xe Summit, 120,000 miles, $24,000, New condition
# Predicted Score: 40.85
#
# Extracted car info: {'Year': 2020, 'Model': 'Toyota Rav4', 'Mileage': 180000, 'Price': 100000, 'Condition': None, 'Dealer': 'CarMax Tinley Park', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 97: Dealer: CarMax Tinley Park. 2020 Toyota RAV4 Adventure, 180,000 miles, $100,000
# Predicted Score: 64.36
#
# Extracted car info: {'Year': 2004, 'Model': 'Mercedes', 'Mileage': 160000, 'Price': 62000, 'Condition': None, 'Dealer': 'AM', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 98: Mercedes-Benz SLS AMG Base from 2004 with 160,000 miles, $62,000
# Predicted Score: 52.58
#
# Extracted car info: {'Year': 2021, 'Model': 'Acura Mdx', 'Mileage': 75000, 'Price': 92000, 'Condition': None, 'Dealer': 'CarMax Independence', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 99: Dealer: CarMax Independence. 2021 Acura MDX A-Spec Package, 75,000 miles, $92,000
# Predicted Score: 57.18
#
# Extracted car info: {'Year': 2004, 'Model': '##YP', 'Mileage': 205000, 'Price': 78000, 'Condition': None, 'Dealer': 'Muller Subaru Volkswagen', 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 0}
# Query 100: 2004 Jaguar F-TYPE R Convertible 2D, 205,000 miles, $78,000, business use, dealer: Muller Subaru Volkswagen
# Predicted Score: 60.93
#
# Extracted car info: {'Year': 2021, 'Model': 'Toyota Camry', 'Mileage': 35000, 'Price': 25000, 'Condition': 'Used', 'Dealer': 'AutoNation', 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 1}
# Query 101: 2021 Toyota Camry with 35,000 miles for $25,000 in used condition from AutoNation, no accidents, 1 owner
# Predicted Score: 43.96
#
# Extracted car info: {'Year': 2019, 'Model': 'Honda Accord', 'Mileage': 75000, 'Price': 18500, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 102: 2019 Honda Accord, 75,000 miles, $18,500, used condition, personal use
# Predicted Score: 37.06
#
# Extracted car info: {'Year': 2022, 'Model': 'Tesla Model 3', 'Mileage': 12000, 'Price': 42000, 'Condition': None, 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 103: Tesla Model 3 2022 with 12,000 miles priced at $42,000, clean history
# Predicted Score: 39.10
#
# Extracted car info: {'Year': 2017, 'Model': 'Ford F - 150', 'Mileage': 120000, 'Price': 22999, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 1, 'Owners': 1, 'Usage': 0}
# Query 104: Ford F-150 2017, 120,000 miles, $22,999, used condition, commercial use, accident reported
# Predicted Score: 46.73
#
# Extracted car info: {'Year': 2018, 'Model': 'Nissan Rogue', 'Mileage': 85000, 'Price': 16500, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 3, 'Usage': 1}
# Query 105: 2018 Nissan Rogue, $16,500, 85,000 miles, used condition, 3 owners
# Predicted Score: 43.74
#
# Extracted car info: {'Year': 2018, 'Model': 'Subaru Baja', 'Mileage': 2000, 'Price': None, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': 500, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 106: 2018 Subaru Baja, $500 per month, 2,000 miles, used condition, 1 owner
# Predicted Score: 36.54
#
# Extracted car info: {'Year': 2022, 'Model': 'Toyota Camry', 'Mileage': 12000, 'Price': 9000, 'Condition': 'Used', 'Dealer': None, 'Monthly Payment': None, 'Accidents': 0, 'Owners': 1, 'Usage': 1}
# Query 107: 2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history
# Predicted Score: 34.34
#
# Min Query: 2022 Toyota Camry with 12,000 miles for $9,000 in used condition, personal use, 1 owner, clean history
# Min Score: 34.34
